# %% [markdown]
# # TS Prophet
# ## Data split in training and test. The last 365 days are the test data.

# %%
from audioop import cross
import itertools
from matplotlib import units
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from prophet import Prophet
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics
from prophet.plot import add_changepoints_to_plot
from prophet.plot import plot_cross_validation_metric
from prophet.plot import plot_plotly, plot_components_plotly

plt.style.use('fivethirtyeight')

from sklearn.metrics import mean_absolute_error,mean_squared_error

from green_city.utils import metrics_dict, datetime2index, index2datetime

# %matplotlib inline

# %%
## MLFLOW ##
import mlflow
from green_city.mlflow_config import get_mlflow_config

flow_conf = get_mlflow_config()
tracking_uri = flow_conf["TRACKING_URI"]
mlflow.set_tracking_uri(flow_conf["TRACKING_URI"])
mlflow.set_experiment(flow_conf["EXPERIMENT_NAME"]);

# %%
## DB CONNECTION ##
from sqlalchemy import create_engine
from decouple import Config, RepositoryEnv

config = Config(RepositoryEnv("../.db_credentials"))

db_connection_credentials = {
    "database": config('POSTGRES_DB'),
    "user": config('POSTGRES_USER'),
    "password": config('POSTGRES_PASSWORD'),
    "host": config('POSTGRES_HOST'),
    "port": config('POSTGRES_PORT'),
}
DB_STRING = "postgresql://{user}:{password}@{host}:{port}/{database}".format(**db_connection_credentials)
db = create_engine(DB_STRING)

# %% [markdown]
# ### Load data and feature engineering

# %%
building = 5
# Load data
df = pd.read_csv(f"../data/preprocessed/Building_{building}.csv").astype({'datetime': 'datetime64'})#.set_index('datetime')

# %%
df = df.rename(columns={'datetime':'ds',
                        'net_load_kWh':'y'})
# df.head(5)

# %%
def is_winter_season(ds):
    date = pd.to_datetime(ds)
    return(date.month < 4 or date.month > 9)

df['winter'] = df['ds'].apply(is_winter_season)
df['summer'] = ~df['ds'].apply(is_winter_season)

# %%
df_holiday = df[['ds','holiday']].query('holiday')
df_holiday['holiday'] = 'Holiday'

# %% [markdown]
# ### Split data in training and test data

# %%
df_train = df[:365*3*24]
df_test = df[365*3*24:]

# %% [markdown]
# ## Prophet simple model. Three years training

# %%
my_model_simple = Prophet(interval_width = 0.95, seasonality_mode="additive")

# %%
my_model_simple.fit(df_train)
# Out:
# Initial log joint probability = -807.326
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       47996.1    0.00499351       258.451           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       48025.4     0.0139303       710.728           1           1      228
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       48037.3    0.00110004       218.145      0.7697      0.7697      342
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      315       48039.4   0.000111663       472.897   1.763e-07       0.001      399  LS failed, Hessian reset
#      399         48046    0.00148367       327.591      0.5189      0.5189      500
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       48052.1    0.00499085       447.872           1           1      621
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       48057.5    0.00195712       574.755           1           1      739
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      627       48058.5   5.61456e-05       203.499    5.45e-07       0.001      815  LS failed, Hessian reset
#      699       48059.2   7.42767e-05       98.3931      0.1626           1      901
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      734       48059.3   2.73479e-06       83.7794      0.2887           1      948
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
pred_indices = [32135, 33311, 26478, 33357, 30387, 30794, 31800, 28783]

# %%
for index in pred_indices:
    with mlflow.start_run(run_name='Prophet Simple Model') as r:
        ### Predict ##
        # my_model_simple.fit(df.loc[:index])
        df_future = df.copy().loc[index+1:index+24]
        df_forecast = my_model_simple.predict(df_future)
        df_forecast.index = df_future.index
        df_forecast.index.name = 'id'
        df_forecast['error'] = df_future.y - df_forecast.yhat
        df_forecast = df_forecast[['yhat', 'error']]
        
        ## Evaluate ##
        metrics = metrics_dict(df_future.y, df_forecast.yhat, ["mae", "mse", "r2_score"])
        print("mae: {mae}, mse: {mse}, r2: {r2_score}".format(**metrics))
        mlflow.log_metrics(metrics)

        ## Parameters log ##
        params = {
            'building_nr': building,
            'datetime':index2datetime(index)
        }
        mlflow.log_params(params)

        forecast = df_forecast[['yhat']].assign(run_id = r.info.run_id).rename(columns={"yhat": "prediction"})
        # forecasts.to_sql("forecast", con=db, if_exists="append")
# Out:
# mae: 5.381091005581283, mse: 47.32219039105721, r2: 0.6440722191468136
# mae: 10.536584487366788, mse: 140.72746586087422, r2: -0.5485944775992997
# mae: 6.671270476282078, mse: 77.8964513625216, r2: -0.3620809874510411
# mae: 10.193935633411757, mse: 136.30121427849497, r2: -0.02802957848261345
# mae: 5.738748299421961, mse: 56.968331333133854, r2: 0.6243512217481284
# mae: 5.3202301169115955, mse: 44.38111760262769, r2: 0.6314194949223908
# mae: 5.278088350438547, mse: 36.56512023161958, r2: 0.6520552918424901
# mae: 6.235855971940784, mse: 64.41949969740966, r2: 0.4406090898519034

# %%
param_grid_simple = {
    'interval_width': [0.95],
    'seasonality_mode':['additive'],
    'yearly_seasonality':['auto'],
    'changepoint_prior_scale':[0.05],
    'seasonality_prior_scale':[10]
}
all_params = [dict(zip(param_grid_simple.keys(), v)) for v in itertools.product(*param_grid_simple.values())]

# %%
def my_prophet(df, all_params):
        rmses = []
        for params in all_params:
                m = Prophet(**params#,
                        # holidays=df_holidays 
                # weekly_seasonality=False
                )
        # m.add_seasonality(name='weekly_on_winter', period = 7, fourier_order=10, condition_name='winter')
        # m.add_seasonality(name='weekly_on_summer', period = 7, fourier_order=10, condition_name='summer')
                m.fit(df_train)
                df_cv = cross_validation(m, horizon='180 days', parallel='processes')
                df_p = performance_metrics(df_cv, rolling_window=1)
                rmses.append(df_p['rmse'].values[0])
        tuning_results = pd.DataFrame(all_params)
        tuning_results['rmse'] = rmses
        print(tuning_results)
        best_params=all_params[np.argmin(rmses)]
        print(best_params)

        my_model = Prophet(**best_params)
        my_model.fit(df)
        return my_model

# %% [markdown]
# Supress logging

# %%
import warnings
import logging
import os

def my_prophet(df, all_params):
    warnings.simplefilter("ignore", DeprecationWarning)
    warnings.simplefilter("ignore", FutureWarning)
    logging.getLogger('prophet').setLevel(logging.ERROR) #Notice that i had modified the name from 'fbprophet' to just 'prophet'
    rmses = []
    for params in all_params:
            m = Prophet(**params#,
                    # holidays=df_holidays 
            # weekly_seasonality=False
            )
    # m.add_seasonality(name='weekly_on_winter', period = 7, fourier_order=10, condition_name='winter')
    # m.add_seasonality(name='weekly_on_summer', period = 7, fourier_order=10, condition_name='summer')
            m.fit(df_train)
            df_cv = cross_validation(m, horizon='180 days', parallel='processes')
            df_p = performance_metrics(df_cv, rolling_window=1)
            rmses.append(df_p['rmse'].values[0])
    tuning_results = pd.DataFrame(all_params)
    tuning_results['rmse'] = rmses
    print(tuning_results)
    best_params=all_params[np.argmin(rmses)]
    print(best_params)

    my_model = Prophet(**best_params)
    my_model.fit(df)
    return my_model

# %%
for index in pred_indices:
    with mlflow.start_run(run_name='Prophet Simple Model w/Params') as r:
        ### Predict ##
        my_model = my_prophet(df=df.loc[:index], all_params=all_params)
        df_future = df.copy().loc[index+1:index+24]
        df_forecast = my_model_simple.predict(df_future)
        df_forecast.index = df_future.index
        df_forecast.index.name = 'id'
        df_forecast['error'] = df_future.y - df_forecast.yhat
        df_forecast = df_forecast[['yhat', 'error']]
        
        ## Evaluate ##
        metrics = metrics_dict(df_future.y, df_forecast.yhat, ["mae", "mse", "r2_score"])
        print(index)
        print("mae: {mae}, mse: {mse}, r2: {r2_score}".format(**metrics))
        mlflow.log_metrics(metrics)

        ## Parameters log ##
        params = {
            'building_nr': building,
            'datetime':index2datetime(index)
        }
        mlflow.log_params(params)

        forecasts = df_forecast[['yhat']].assign(run_id = r.info.run_id).rename(columns={"yhat": "prediction"})
        # forecasts.to_sql("forecast", con=db, if_exists="append")
# Out:
# Initial log joint probability = -807.326
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       47996.1    0.00499351       258.451           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       48025.4     0.0139303       710.728           1           1      228
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       48037.3    0.00110004       218.145      0.7697      0.7697      342
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      315       48039.4   0.000111663       472.897   1.763e-07       0.001      399  LS failed, Hessian reset
#      399         48046    0.00148367       327.591      0.5189      0.5189      500
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       48052.1    0.00499085       447.872           1           1      621
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       48057.5    0.00195712       574.755           1           1      739
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      627       48058.5   5.61456e-05       203.499    5.45e-07       0.001      815  LS failed, Hessian reset
#      699       48059.2   7.42767e-05       98.3931      0.1626           1      901
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      734       48059.3   2.73479e-06       83.7794      0.2887           1      948
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -747.724
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -281.71
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -428.461
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -663.969
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -449.35
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99         23948     0.0128173       752.362           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       31362.9     0.0376001       279.571           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       28046.6    0.00534776       237.466           1           1      123
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       35080.1    0.00651879       702.545           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       23954.2    0.00368025       181.403      0.8046      0.8046      241
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       40075.3    0.00650193       762.558           1           1      116
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      205       23954.4   0.000188938         231.6   1.344e-06       0.001      295  LS failed, Hessian reset
#      199       28053.8    0.00161055       77.3401           1           1      243
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       31374.3    0.00680612       671.584      0.4508           1      250
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       23955.6   1.41657e-05       84.6407      0.3482           1      420
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      165         35089   0.000118435       328.623   4.492e-07       0.001      259  LS failed, Hessian reset
#      299       28058.4   0.000510387       111.521      0.8617      0.8617      358
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       40089.3    0.00605297       493.202      0.3041           1      233
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       35091.4    0.00120386       134.641           1           1      297
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       31380.7    0.00276276       194.277      0.9073      0.9073      376
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      376       23956.7   0.000222871       357.071   9.592e-07       0.001      563  LS failed, Hessian reset
#      343       28059.7   9.52822e-05       184.759   2.218e-07       0.001      458  LS failed, Hessian reset
#      399       23957.2   0.000274238       111.529      0.8755      0.8755      588
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      335       31381.3   0.000115792       191.567   9.443e-07       0.001      472  LS failed, Hessian reset
#      399       28060.7   0.000138879       79.5746      0.8817      0.8817      519
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      468       23957.5   1.37927e-06       68.8076      0.2219           1      683
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      299       40098.6    0.00173267        382.76      0.4179      0.4179      354
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       35094.6   0.000825389       184.707        1.02       0.102      417
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       31382.2   0.000459665       142.231       0.012           1      560
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499         28062   0.000130435       317.386      0.5705      0.5705      637
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      326       35095.4   3.24016e-05       87.0623   2.072e-07       0.001      501  LS failed, Hessian reset
#      433       31382.7   4.79434e-05       140.104   3.562e-07       0.001      634  LS failed, Hessian reset
#      399       40101.2    0.00105941        136.41           1           1      477
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       28063.8    0.00147618       93.0383           1           1      758
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      360       35097.7   0.000121645       310.485   2.204e-07       0.001      584  LS failed, Hessian reset
#      486       31383.3   6.05157e-05       166.827   4.609e-07       0.001      744  LS failed, Hessian reset
#      499       31383.8   0.000172823       188.951      0.2849      0.8229      760
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       35099.5    0.00284747       190.821           1           1      636
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      660       28064.2   0.000587044       157.737   4.608e-06       0.001      892  LS failed, Hessian reset
#      499       40104.2    0.00379588       213.539           1           1      606
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       28064.2    4.5135e-05       89.6772      0.2919      0.2919      939
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       31384.4   2.01565e-05       72.7401      0.3803      0.3803      884
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       35101.2    0.00178457       128.078           1           1      758
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      764       28064.5   0.000199054       143.976   2.323e-06       0.001     1070  LS failed, Hessian reset
#      561       40105.5   9.72211e-05       183.639   1.066e-06       0.001      730  LS failed, Hessian reset
#      799       28064.5   1.79541e-05       65.6891           1           1     1119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      536       35101.9   0.000110851       256.661    6.36e-07       0.001      852  LS failed, Hessian reset
#      699       31388.1    0.00339474       442.223           1           1     1010
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      802       28064.5   8.79688e-06       70.1868   1.214e-07       0.001     1171  LS failed, Hessian reset
#      599       40105.7   0.000164241       121.772           1           1      777
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      812       28064.5   1.27002e-06       54.6798      0.3318           1     1182
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      583       35102.6   6.04203e-05       128.775   7.545e-07       0.001      946  LS failed, Hessian reset
#      599       35102.6   0.000105033       107.393           1           1      965
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      798       31390.5   5.76914e-05       150.684   3.374e-07       0.001     1188  LS failed, Hessian reset
#      799       31390.5   3.86172e-05       122.492           1           1     1189
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       40107.9   0.000365013       157.415       0.805       0.805      890
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       35104.7   0.000311356        122.58      0.6475      0.6475     1090
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      891       31391.2   3.90296e-05       128.819   2.731e-07       0.001     1330  LS failed, Hessian reset
#      899       31391.3   0.000388281       126.896       0.329           1     1340
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       40108.6   5.78991e-06       74.0208      0.2592      0.2592     1010
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       31391.7   0.000452032       113.108       0.427      0.1459     1464
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      791       35106.4    3.9371e-05       117.072   2.376e-07       0.001     1253  LS failed, Hessian reset
#      799       35106.4   4.40973e-05       95.9465      0.2514           1     1264
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899         40109   4.48867e-05        75.507      0.8036      0.8036     1131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1092       31391.9   1.34376e-06       70.1707     0.01606      0.6375     1582
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      916       40109.2   0.000337082       271.443   3.824e-06       0.001     1197  LS failed, Hessian reset
#      899       35106.5   1.31602e-05         75.33      0.2121      0.7044     1396
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      968       40109.3   1.90433e-05       66.6716   2.479e-07       0.001     1308  LS failed, Hessian reset
#      979       40109.3   1.21964e-06       88.1476       0.286       0.286     1323
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      999       35108.5    0.00102966       237.479           1           1     1517
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1074       35108.9   4.15331e-05       119.651    4.32e-07       0.001     1654  LS failed, Hessian reset
#     1099         35109   0.000402249       77.6647           1           1     1690
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1128       35109.4    9.3975e-05       182.505   7.504e-07       0.001     1781  LS failed, Hessian reset
#     1183       35109.6   2.40575e-05       77.4506   1.933e-07       0.001     1893  LS failed, Hessian reset
#     1199       35109.7   3.39629e-06       59.6966      0.4915      0.4915     1910
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1202       35109.7   2.97166e-06        59.585      0.9706      0.9706     1913
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#    interval_width seasonality_mode yearly_seasonality  \
# 0            0.95         additive               auto
#
#    changepoint_prior_scale  seasonality_prior_scale       rmse
# 0                     0.05                       10  12.882032
# {'interval_width': 0.95, 'seasonality_mode': 'additive', 'yearly_seasonality': 'auto', 'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 10}
# Initial log joint probability = -695.89
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       58172.6     0.0136807       431.707           1           1      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       58195.6     0.0123407       1046.41           1           1      239
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       58208.1    0.00380066       698.799           1           1      356
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       58215.8   0.000790774       263.301           1           1      478
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       58219.6     0.0034487       376.535           1           1      598
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       58221.1    0.00262478         483.1           1           1      732
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       58226.3    0.00415204       268.006           1           1      846
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      780         58227   4.27531e-05       129.612   6.389e-07       0.001      981  LS failed, Hessian reset
#      799       58227.1   0.000517962       111.365           1           1     1002
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      896       58228.8   7.11868e-05       226.047   4.341e-07       0.001     1157  LS failed, Hessian reset
#      899       58228.8   0.000108841       140.983           1           1     1160
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       58229.8   0.000327321       168.423      0.4981      0.4981     1286
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1023       58229.9   1.66837e-05        89.484   1.544e-07       0.001     1373  LS failed, Hessian reset
#     1099       58230.2   0.000329854       65.7237           1           1     1467
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       58231.9   0.000677684       225.181           1           1     1590
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       58232.6   0.000521314       139.648           1           1     1713
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399         58233   5.69673e-05       119.232      0.7995      0.7995     1842
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1406       58233.1   4.66476e-05       147.983   5.664e-07       0.001     1900  LS failed, Hessian reset
#     1433       58233.1   2.26368e-06       58.8826      0.1625           1     1936
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 32135
# mae: 5.381091005581283, mse: 47.32219039105721, r2: 0.6440722191468136
# Initial log joint probability = -807.326
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       47996.1    0.00499351       258.451           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       48025.4     0.0139303       710.728           1           1      228
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       48037.3    0.00110004       218.145      0.7697      0.7697      342
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      315       48039.4   0.000111663       472.897   1.763e-07       0.001      399  LS failed, Hessian reset
#      399         48046    0.00148367       327.591      0.5189      0.5189      500
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       48052.1    0.00499085       447.872           1           1      621
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       48057.5    0.00195712       574.755           1           1      739
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      627       48058.5   5.61456e-05       203.499    5.45e-07       0.001      815  LS failed, Hessian reset
#      699       48059.2   7.42767e-05       98.3931      0.1626           1      901
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      734       48059.3   2.73479e-06       83.7794      0.2887           1      948
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -663.969
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -747.724
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -281.71
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -449.35
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -428.461
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99         23948     0.0128173       752.362           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       31362.9     0.0376001       279.571           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       28046.6    0.00534776       237.466           1           1      123
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       35080.1    0.00651879       702.545           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       40075.3    0.00650193       762.558           1           1      116
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       23954.2    0.00368025       181.403      0.8046      0.8046      241
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      205       23954.4   0.000188938         231.6   1.344e-06       0.001      295  LS failed, Hessian reset
#      199       28053.8    0.00161055       77.3401           1           1      243
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       31374.3    0.00680612       671.584      0.4508           1      250
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      165         35089   0.000118435       328.623   4.492e-07       0.001      259  LS failed, Hessian reset
#      299       23955.6   1.41657e-05       84.6407      0.3482           1      420
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       40089.3    0.00605297       493.202      0.3041           1      233
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       28058.4   0.000510387       111.521      0.8617      0.8617      358
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       35091.4    0.00120386       134.641           1           1      297
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       31380.7    0.00276276       194.277      0.9073      0.9073      376
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      376       23956.7   0.000222871       357.071   9.592e-07       0.001      563  LS failed, Hessian reset
#      343       28059.7   9.52822e-05       184.759   2.218e-07       0.001      458  LS failed, Hessian reset
#      399       23957.2   0.000274238       111.529      0.8755      0.8755      588
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       28060.7   0.000138879       79.5746      0.8817      0.8817      519
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       35094.6   0.000825389       184.707        1.02       0.102      417
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      335       31381.3   0.000115792       191.567   9.443e-07       0.001      472  LS failed, Hessian reset
#      299       40098.6    0.00173267        382.76      0.4179      0.4179      354
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      468       23957.5   1.37927e-06       68.8076      0.2219           1      683
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      326       35095.4   3.24016e-05       87.0623   2.072e-07       0.001      501  LS failed, Hessian reset
#      399       31382.2   0.000459665       142.231       0.012           1      560
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499         28062   0.000130435       317.386      0.5705      0.5705      637
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       40101.2    0.00105941        136.41           1           1      477
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      433       31382.7   4.79434e-05       140.104   3.562e-07       0.001      634  LS failed, Hessian reset
#      360       35097.7   0.000121645       310.485   2.204e-07       0.001      584  LS failed, Hessian reset
#      599       28063.8    0.00147618       93.0383           1           1      758
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       35099.5    0.00284747       190.821           1           1      636
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      486       31383.3   6.05157e-05       166.827   4.609e-07       0.001      744  LS failed, Hessian reset
#      499       31383.8   0.000172823       188.951      0.2849      0.8229      760
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       40104.2    0.00379588       213.539           1           1      606
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      660       28064.2   0.000587044       157.737   4.608e-06       0.001      892  LS failed, Hessian reset
#      699       28064.2    4.5135e-05       89.6772      0.2919      0.2919      939
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       35101.2    0.00178457       128.078           1           1      758
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       31384.4   2.01565e-05       72.7401      0.3803      0.3803      884
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      561       40105.5   9.72211e-05       183.639   1.066e-06       0.001      730  LS failed, Hessian reset
#      764       28064.5   0.000199054       143.976   2.323e-06       0.001     1070  LS failed, Hessian reset
#      536       35101.9   0.000110851       256.661    6.36e-07       0.001      852  LS failed, Hessian reset
#      799       28064.5   1.79541e-05       65.6891           1           1     1119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       40105.7   0.000164241       121.772           1           1      777
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       31388.1    0.00339474       442.223           1           1     1010
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      802       28064.5   8.79688e-06       70.1868   1.214e-07       0.001     1171  LS failed, Hessian reset
#      812       28064.5   1.27002e-06       54.6798      0.3318           1     1182
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      583       35102.6   6.04203e-05       128.775   7.545e-07       0.001      946  LS failed, Hessian reset
#      599       35102.6   0.000105033       107.393           1           1      965
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       40107.9   0.000365013       157.415       0.805       0.805      890
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      798       31390.5   5.76914e-05       150.684   3.374e-07       0.001     1188  LS failed, Hessian reset
#      799       31390.5   3.86172e-05       122.492           1           1     1189
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       35104.7   0.000311356        122.58      0.6475      0.6475     1090
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       40108.6   5.78991e-06       74.0208      0.2592      0.2592     1010
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      891       31391.2   3.90296e-05       128.819   2.731e-07       0.001     1330  LS failed, Hessian reset
#      899       31391.3   0.000388281       126.896       0.329           1     1340
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      791       35106.4    3.9371e-05       117.072   2.376e-07       0.001     1253  LS failed, Hessian reset
#      799       35106.4   4.40973e-05       95.9465      0.2514           1     1264
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899         40109   4.48867e-05        75.507      0.8036      0.8036     1131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       31391.7   0.000452032       113.108       0.427      0.1459     1464
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      916       40109.2   0.000337082       271.443   3.824e-06       0.001     1197  LS failed, Hessian reset
#      899       35106.5   1.31602e-05         75.33      0.2121      0.7044     1396
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1092       31391.9   1.34376e-06       70.1707     0.01606      0.6375     1582
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      968       40109.3   1.90433e-05       66.6716   2.479e-07       0.001     1308  LS failed, Hessian reset
#      979       40109.3   1.21964e-06       88.1476       0.286       0.286     1323
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      999       35108.5    0.00102966       237.479           1           1     1517
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1074       35108.9   4.15331e-05       119.651    4.32e-07       0.001     1654  LS failed, Hessian reset
#     1099         35109   0.000402249       77.6647           1           1     1690
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1128       35109.4    9.3975e-05       182.505   7.504e-07       0.001     1781  LS failed, Hessian reset
#     1183       35109.6   2.40575e-05       77.4506   1.933e-07       0.001     1893  LS failed, Hessian reset
#     1199       35109.7   3.39629e-06       59.6966      0.4915      0.4915     1910
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1202       35109.7   2.97166e-06        59.585      0.9706      0.9706     1913
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#    interval_width seasonality_mode yearly_seasonality  \
# 0            0.95         additive               auto
#
#    changepoint_prior_scale  seasonality_prior_scale       rmse
# 0                     0.05                       10  12.882032
# {'interval_width': 0.95, 'seasonality_mode': 'additive', 'yearly_seasonality': 'auto', 'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 10}
# Initial log joint probability = -798.708
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       60126.1     0.0398602       2619.07      0.4996           1      120
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       60176.5     0.0196736       881.354           1           1      236
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      254       60180.5   2.88294e-05       147.847   2.181e-07       0.001      344  LS failed, Hessian reset
#      299         60182     0.0172614       551.166           1           1      393
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       60191.8     0.0013809       357.035      0.4622      0.4622      506
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       60196.8    0.00163053       258.877        9.33       0.933      624
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       60198.2    0.00247986        384.73       1.039      0.1039      739
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      659       60199.2    6.8654e-05       133.902   9.751e-07       0.001      863  LS failed, Hessian reset
#      699       60199.3   8.94502e-05       79.4893           1           1      916
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       60202.2   0.000121742       89.6029      0.3156           1     1027
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899         60203    0.00015673       134.632           1           1     1150
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      961       60203.7   3.56781e-05       130.339   9.887e-08       0.001     1281  LS failed, Hessian reset
#      999         60204   3.26101e-05       368.869     0.01549           1     1328
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1033       60204.1   1.22869e-05       67.2678   1.336e-07       0.001     1413  LS failed, Hessian reset
#     1099       60204.2   0.000846769       402.967      0.8388      0.8388     1493
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       60207.2   0.000151293       139.744           1           1     1607
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       60208.3   0.000209686       106.479           1           1     1741
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1359       60208.5   8.54359e-06       55.4464     0.06186      0.8091     1823
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 33311
# mae: 10.536584487366788, mse: 140.72746586087422, r2: -0.5485944775992997
# Initial log joint probability = -807.326
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       47996.1    0.00499351       258.451           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       48025.4     0.0139303       710.728           1           1      228
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       48037.3    0.00110004       218.145      0.7697      0.7697      342
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      315       48039.4   0.000111663       472.897   1.763e-07       0.001      399  LS failed, Hessian reset
#      399         48046    0.00148367       327.591      0.5189      0.5189      500
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       48052.1    0.00499085       447.872           1           1      621
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       48057.5    0.00195712       574.755           1           1      739
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      627       48058.5   5.61456e-05       203.499    5.45e-07       0.001      815  LS failed, Hessian reset
#      699       48059.2   7.42767e-05       98.3931      0.1626           1      901
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      734       48059.3   2.73479e-06       83.7794      0.2887           1      948
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -281.71
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -663.969
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -428.461
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -449.35
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -747.724
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99         23948     0.0128173       752.362           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       28046.6    0.00534776       237.466           1           1      123
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       35080.1    0.00651879       702.545           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       31362.9     0.0376001       279.571           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       23954.2    0.00368025       181.403      0.8046      0.8046      241
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       40075.3    0.00650193       762.558           1           1      116
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      205       23954.4   0.000188938         231.6   1.344e-06       0.001      295  LS failed, Hessian reset
#      199       28053.8    0.00161055       77.3401           1           1      243
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       23955.6   1.41657e-05       84.6407      0.3482           1      420
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       31374.3    0.00680612       671.584      0.4508           1      250
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      165         35089   0.000118435       328.623   4.492e-07       0.001      259  LS failed, Hessian reset
#      299       28058.4   0.000510387       111.521      0.8617      0.8617      358
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       40089.3    0.00605297       493.202      0.3041           1      233
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       35091.4    0.00120386       134.641           1           1      297
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      376       23956.7   0.000222871       357.071   9.592e-07       0.001      563  LS failed, Hessian reset
#      399       23957.2   0.000274238       111.529      0.8755      0.8755      588
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      343       28059.7   9.52822e-05       184.759   2.218e-07       0.001      458  LS failed, Hessian reset
#      299       31380.7    0.00276276       194.277      0.9073      0.9073      376
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       28060.7   0.000138879       79.5746      0.8817      0.8817      519
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      468       23957.5   1.37927e-06       68.8076      0.2219           1      683
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      299       40098.6    0.00173267        382.76      0.4179      0.4179      354
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       35094.6   0.000825389       184.707        1.02       0.102      417
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      335       31381.3   0.000115792       191.567   9.443e-07       0.001      472  LS failed, Hessian reset
#      499         28062   0.000130435       317.386      0.5705      0.5705      637
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      326       35095.4   3.24016e-05       87.0623   2.072e-07       0.001      501  LS failed, Hessian reset
#      399       31382.2   0.000459665       142.231       0.012           1      560
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       40101.2    0.00105941        136.41           1           1      477
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       28063.8    0.00147618       93.0383           1           1      758
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      360       35097.7   0.000121645       310.485   2.204e-07       0.001      584  LS failed, Hessian reset
#      433       31382.7   4.79434e-05       140.104   3.562e-07       0.001      634  LS failed, Hessian reset
#      399       35099.5    0.00284747       190.821           1           1      636
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      660       28064.2   0.000587044       157.737   4.608e-06       0.001      892  LS failed, Hessian reset
#      486       31383.3   6.05157e-05       166.827   4.609e-07       0.001      744  LS failed, Hessian reset
#      499       31383.8   0.000172823       188.951      0.2849      0.8229      760
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       40104.2    0.00379588       213.539           1           1      606
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       28064.2    4.5135e-05       89.6772      0.2919      0.2919      939
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       35101.2    0.00178457       128.078           1           1      758
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       31384.4   2.01565e-05       72.7401      0.3803      0.3803      884
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      764       28064.5   0.000199054       143.976   2.323e-06       0.001     1070  LS failed, Hessian reset
#      561       40105.5   9.72211e-05       183.639   1.066e-06       0.001      730  LS failed, Hessian reset
#      536       35101.9   0.000110851       256.661    6.36e-07       0.001      852  LS failed, Hessian reset
#      799       28064.5   1.79541e-05       65.6891           1           1     1119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      802       28064.5   8.79688e-06       70.1868   1.214e-07       0.001     1171  LS failed, Hessian reset
#      599       40105.7   0.000164241       121.772           1           1      777
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      812       28064.5   1.27002e-06       54.6798      0.3318           1     1182
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      699       31388.1    0.00339474       442.223           1           1     1010
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      583       35102.6   6.04203e-05       128.775   7.545e-07       0.001      946  LS failed, Hessian reset
#      599       35102.6   0.000105033       107.393           1           1      965
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       40107.9   0.000365013       157.415       0.805       0.805      890
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      798       31390.5   5.76914e-05       150.684   3.374e-07       0.001     1188  LS failed, Hessian reset
#      799       31390.5   3.86172e-05       122.492           1           1     1189
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       35104.7   0.000311356        122.58      0.6475      0.6475     1090
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       40108.6   5.78991e-06       74.0208      0.2592      0.2592     1010
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      891       31391.2   3.90296e-05       128.819   2.731e-07       0.001     1330  LS failed, Hessian reset
#      899       31391.3   0.000388281       126.896       0.329           1     1340
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      791       35106.4    3.9371e-05       117.072   2.376e-07       0.001     1253  LS failed, Hessian reset
#      799       35106.4   4.40973e-05       95.9465      0.2514           1     1264
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899         40109   4.48867e-05        75.507      0.8036      0.8036     1131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       31391.7   0.000452032       113.108       0.427      0.1459     1464
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      916       40109.2   0.000337082       271.443   3.824e-06       0.001     1197  LS failed, Hessian reset
#      899       35106.5   1.31602e-05         75.33      0.2121      0.7044     1396
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1092       31391.9   1.34376e-06       70.1707     0.01606      0.6375     1582
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      968       40109.3   1.90433e-05       66.6716   2.479e-07       0.001     1308  LS failed, Hessian reset
#      979       40109.3   1.21964e-06       88.1476       0.286       0.286     1323
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      999       35108.5    0.00102966       237.479           1           1     1517
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1074       35108.9   4.15331e-05       119.651    4.32e-07       0.001     1654  LS failed, Hessian reset
#     1099         35109   0.000402249       77.6647           1           1     1690
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1128       35109.4    9.3975e-05       182.505   7.504e-07       0.001     1781  LS failed, Hessian reset
#     1183       35109.6   2.40575e-05       77.4506   1.933e-07       0.001     1893  LS failed, Hessian reset
# ...
#      299       48037.3    0.00110004       218.145      0.7697      0.7697      342
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      315       48039.4   0.000111663       472.897   1.763e-07       0.001      399  LS failed, Hessian reset
#      399         48046    0.00148367       327.591      0.5189      0.5189      500
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       48052.1    0.00499085       447.872           1           1      621
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       48057.5    0.00195712       574.755           1           1      739
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      627       48058.5   5.61456e-05       203.499    5.45e-07       0.001      815  LS failed, Hessian reset
#      699       48059.2   7.42767e-05       98.3931      0.1626           1      901
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      734       48059.3   2.73479e-06       83.7794      0.2887           1      948
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -449.35
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -747.724
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -428.461
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -281.71
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -663.969
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99         23948     0.0128173       752.362           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       28046.6    0.00534776       237.466           1           1      123
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       31362.9     0.0376001       279.571           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       40075.3    0.00650193       762.558           1           1      116
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       35080.1    0.00651879       702.545           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       23954.2    0.00368025       181.403      0.8046      0.8046      241
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       28053.8    0.00161055       77.3401           1           1      243
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      205       23954.4   0.000188938         231.6   1.344e-06       0.001      295  LS failed, Hessian reset
#      199       31374.3    0.00680612       671.584      0.4508           1      250
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       40089.3    0.00605297       493.202      0.3041           1      233
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       23955.6   1.41657e-05       84.6407      0.3482           1      420
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       28058.4   0.000510387       111.521      0.8617      0.8617      358
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      165         35089   0.000118435       328.623   4.492e-07       0.001      259  LS failed, Hessian reset
#      199       35091.4    0.00120386       134.641           1           1      297
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       31380.7    0.00276276       194.277      0.9073      0.9073      376
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      343       28059.7   9.52822e-05       184.759   2.218e-07       0.001      458  LS failed, Hessian reset
#      376       23956.7   0.000222871       357.071   9.592e-07       0.001      563  LS failed, Hessian reset
#      399       23957.2   0.000274238       111.529      0.8755      0.8755      588
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       40098.6    0.00173267        382.76      0.4179      0.4179      354
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       28060.7   0.000138879       79.5746      0.8817      0.8817      519
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      335       31381.3   0.000115792       191.567   9.443e-07       0.001      472  LS failed, Hessian reset
#      468       23957.5   1.37927e-06       68.8076      0.2219           1      683
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      299       35094.6   0.000825389       184.707        1.02       0.102      417
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499         28062   0.000130435       317.386      0.5705      0.5705      637
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       31382.2   0.000459665       142.231       0.012           1      560
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       40101.2    0.00105941        136.41           1           1      477
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      326       35095.4   3.24016e-05       87.0623   2.072e-07       0.001      501  LS failed, Hessian reset
#      433       31382.7   4.79434e-05       140.104   3.562e-07       0.001      634  LS failed, Hessian reset
#      599       28063.8    0.00147618       93.0383           1           1      758
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      360       35097.7   0.000121645       310.485   2.204e-07       0.001      584  LS failed, Hessian reset
#      486       31383.3   6.05157e-05       166.827   4.609e-07       0.001      744  LS failed, Hessian reset
#      499       40104.2    0.00379588       213.539           1           1      606
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       35099.5    0.00284747       190.821           1           1      636
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       31383.8   0.000172823       188.951      0.2849      0.8229      760
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      660       28064.2   0.000587044       157.737   4.608e-06       0.001      892  LS failed, Hessian reset
#      699       28064.2    4.5135e-05       89.6772      0.2919      0.2919      939
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       31384.4   2.01565e-05       72.7401      0.3803      0.3803      884
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       35101.2    0.00178457       128.078           1           1      758
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      561       40105.5   9.72211e-05       183.639   1.066e-06       0.001      730  LS failed, Hessian reset
#      764       28064.5   0.000199054       143.976   2.323e-06       0.001     1070  LS failed, Hessian reset
#      799       28064.5   1.79541e-05       65.6891           1           1     1119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       40105.7   0.000164241       121.772           1           1      777
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      536       35101.9   0.000110851       256.661    6.36e-07       0.001      852  LS failed, Hessian reset
#      802       28064.5   8.79688e-06       70.1868   1.214e-07       0.001     1171  LS failed, Hessian reset
#      812       28064.5   1.27002e-06       54.6798      0.3318           1     1182
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      699       31388.1    0.00339474       442.223           1           1     1010
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      583       35102.6   6.04203e-05       128.775   7.545e-07       0.001      946  LS failed, Hessian reset
#      699       40107.9   0.000365013       157.415       0.805       0.805      890
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       35102.6   0.000105033       107.393           1           1      965
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      798       31390.5   5.76914e-05       150.684   3.374e-07       0.001     1188  LS failed, Hessian reset
#      799       31390.5   3.86172e-05       122.492           1           1     1189
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       40108.6   5.78991e-06       74.0208      0.2592      0.2592     1010
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       35104.7   0.000311356        122.58      0.6475      0.6475     1090
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      891       31391.2   3.90296e-05       128.819   2.731e-07       0.001     1330  LS failed, Hessian reset
#      899       31391.3   0.000388281       126.896       0.329           1     1340
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899         40109   4.48867e-05        75.507      0.8036      0.8036     1131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      791       35106.4    3.9371e-05       117.072   2.376e-07       0.001     1253  LS failed, Hessian reset
#      799       35106.4   4.40973e-05       95.9465      0.2514           1     1264
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       31391.7   0.000452032       113.108       0.427      0.1459     1464
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      916       40109.2   0.000337082       271.443   3.824e-06       0.001     1197  LS failed, Hessian reset
#     1092       31391.9   1.34376e-06       70.1707     0.01606      0.6375     1582
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      899       35106.5   1.31602e-05         75.33      0.2121      0.7044     1396
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      968       40109.3   1.90433e-05       66.6716   2.479e-07       0.001     1308  LS failed, Hessian reset
#      979       40109.3   1.21964e-06       88.1476       0.286       0.286     1323
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      999       35108.5    0.00102966       237.479           1           1     1517
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1074       35108.9   4.15331e-05       119.651    4.32e-07       0.001     1654  LS failed, Hessian reset
#     1099         35109   0.000402249       77.6647           1           1     1690
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1128       35109.4    9.3975e-05       182.505   7.504e-07       0.001     1781  LS failed, Hessian reset
#     1183       35109.6   2.40575e-05       77.4506   1.933e-07       0.001     1893  LS failed, Hessian reset
#     1199       35109.7   3.39629e-06       59.6966      0.4915      0.4915     1910
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1202       35109.7   2.97166e-06        59.585      0.9706      0.9706     1913
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#    interval_width seasonality_mode yearly_seasonality  \
# 0            0.95         additive               auto
#
#    changepoint_prior_scale  seasonality_prior_scale       rmse
# 0                     0.05                       10  12.882032
# {'interval_width': 0.95, 'seasonality_mode': 'additive', 'yearly_seasonality': 'auto', 'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 10}
# Initial log joint probability = -596.82
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       51990.8    0.00638461       827.357           1           1      118
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       52022.1    0.00132733       312.857      0.2302           1      238
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       52033.3     0.0128455       1285.81           1           1      353
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       52041.8   0.000286308        159.61           1           1      466
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       52047.6    0.00142634       192.768           1           1      592
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       52049.7   0.000328726       263.162      0.5601      0.5601      714
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      631       52050.2   6.17506e-05       192.517   6.082e-07       0.001      798  LS failed, Hessian reset
#      699       52051.1   0.000780473       106.088      0.2694           1      886
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       52052.7    0.00023684       180.257      0.5951      0.5951     1005
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       52053.7   2.59303e-05       79.6355      0.7648      0.7648     1131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      923       52053.9   1.83109e-05       85.3208   1.299e-07       0.001     1216  LS failed, Hessian reset
#      971       52054.1   3.69382e-05       154.448   3.827e-07       0.001     1314  LS failed, Hessian reset
#      992       52054.1   4.94539e-06       69.6597      0.4054           1     1340
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 28783
# mae: 6.235855971940784, mse: 64.41949969740966, r2: 0.4406090898519034

# %%
future_dates = my_model.make_future_dataframe(periods = 365)
# future_dates

# %% [markdown]
# ### Add holidays

# %%
df_holiday = df[['ds','holiday']].query('holiday')
df_holiday['holiday'] = 'Holiday'
# df_holiday

# %%
df_workday = df[['ds','workday']].query('workday')
df_workday['holiday'] = 'Workday'
df_workday = df_workday.drop('workday', axis=1)

# %%
df_holidays = pd.concat([df_holiday, df_workday], ignore_index=True)

# %%
# df_holidays

# %%
my_model = Prophet(interval_width = 0.95, seasonality_mode='additive',
                    holidays=df_holidays)
my_model.fit(df)

# %%
forecast = my_model.predict(future_dates)

# %%
forecast[(forecast['Holiday']+ forecast['Workday']).abs()>0][
    ['ds','Holiday','Workday']]
# forecast[(forecast['Holiday']+ forecast['Workday']).abs()>0][
#     ['ds','Holiday','Workday']][-10:]

# %%
fig = my_model.plot_components(forecast)

# %%
df_cv = cross_validation(my_model, horizon = '180 days', parallel='processes')

# %%
df_cv_pm = performance_metrics(df_cv)

# %%
df_cv_pm

# %% [markdown]
# ### Fourier Order for Seasonalities

# %%
my_model = Prophet(interval_width = 0.95, seasonality_mode='additive',
                    holidays=df_holidays, yearly_seasonality=3)
my_model.fit(df)

# %%
fig = my_model.plot_components(forecast)

# %%
df_cv = cross_validation(my_model, horizon = '180 days', parallel='processes')
df_cv_pm = performance_metrics(df_cv)
df_cv_pm

# %% [markdown]
# ### Assume different weekly sesonalities. Summer vs Winter

# %%
def is_winter_season(ds):
    date = pd.to_datetime(ds)
    return(date.month < 4 or date.month > 9)

df['winter'] = df['ds'].apply(is_winter_season)
df['summer'] = ~df['ds'].apply(is_winter_season)

# %%
my_model = Prophet(interval_width = 0.95, seasonality_mode='additive',
                    holidays=df_holidays, weekly_seasonality=False)
my_model.add_seasonality(name='weekly_on_winter', period = 7, fourier_order=10, condition_name='winter')
my_model.add_seasonality(name='weekly_on_summer', period = 7, fourier_order=10, condition_name='summer')
my_model.fit(df)

# %%
future_dates['winter'] = future_dates['ds'].apply(is_winter_season)
future_dates['summer'] = ~future_dates['ds'].apply(is_winter_season)
forecast = my_model.predict(future_dates)
forecast

# %%
fig = my_model.plot(forecast, uncertainty=True)

# %%
fig = my_model.plot_components(forecast)

# %%
df_cv = cross_validation(my_model, horizon = '180 days', parallel='processes')
df_cv_pm = performance_metrics(df_cv)
df_cv_pm

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='rmse')

# %% [markdown]
# ### Review Holidays parameter. Select only true holidays, do not count for working days

# %%
df_holidays = df_holiday
my_model = Prophet(interval_width = 0.95, seasonality_mode='additive',
                    holidays=df_holidays, weekly_seasonality=False)
my_model.add_seasonality(name='weekly_on_winter', period = 7, fourier_order=10, condition_name='winter')
my_model.add_seasonality(name='weekly_on_summer', period = 7, fourier_order=10, condition_name='summer')
my_model.fit(df)
forecast = my_model.predict(future_dates)
fig = my_model.plot(forecast, uncertainty=True)

# %%
fig = my_model.plot_components(forecast)

# %%
df_cv = cross_validation(my_model, horizon = '180 days', parallel='processes')
df_cv_pm = performance_metrics(df_cv)
df_cv_pm

# %%
fig = plot_cross_validation_metric(df_cv, metric='rmse')

# %% [markdown]
# ### Hyperparameter tunning

# %%
param_grid = {
    'changepoint_prior_scale':[0.0001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale':[0.01, 0.1, 1.0, 10.0]
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = [] # Store the RMSEs for each params her

# Use cross valiation to evaluate all parameters
for params in all_params:
    m = Prophet(**params, 
                interval_width = 0.95, 
                seasonality_mode='additive',
                holidays=df_holidays, 
                weekly_seasonality=False)
    m.add_seasonality(name='weekly_on_winter', period = 7, fourier_order=10, condition_name='winter')
    m.add_seasonality(name='weekly_on_summer', period = 7, fourier_order=10, condition_name='summer')
    m.fit(df)
    df_cv = cross_validation(m, horizon='180 days', parallel='processes')
    df_p = performance_metrics(df_cv, rolling_window=1)
    rmses.append(df_p['rmse'].values[0])

#Find the best parameter
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = rmses
print(tuning_results)

# %%
best_params = all_params[np.argmin(rmses)]
print(best_params)

# %% [markdown]
# ### Train best model

# %%
df_holidays = df_holiday
my_model = Prophet(interval_width = 0.95, seasonality_mode='additive',
                    holidays=df_holidays, weekly_seasonality=False,
                    **best_params)
my_model.add_seasonality(name='weekly_on_winter', period = 7, fourier_order=10, condition_name='winter')
my_model.add_seasonality(name='weekly_on_summer', period = 7, fourier_order=10, condition_name='summer')
my_model.fit(df)
forecast = my_model.predict(future_dates)
fig = my_model.plot(forecast, uncertainty=True)

# %%
fig = my_model.plot_components(forecast)

# %%
df_cv = cross_validation(my_model, horizon = '180 days', parallel='processes')
df_cv_pm = performance_metrics(df_cv)
df_cv_pm

# %% [markdown]
# ## Assesment with training data

# %%
y_test['winter'] = y_test['ds'].apply(is_winter_season)
y_test['summer'] = ~y_test['ds'].apply(is_winter_season)
forecast = my_model.predict(y_test.drop('y', axis=1))
forecast

# %%
print(f"Mean Absolute Error = {mean_absolute_error(y_test['y'], forecast['yhat']).round(3)}")
print(f"Mean Squared Error = {mean_squared_error(y_test['y'], forecast['yhat']).round(3)}")

# %%
df.columns

# %% [markdown]
# ### Add outdoor temperature as additional regressor.

# %%
df_holidays = df_holiday
my_model = Prophet(interval_width = 0.95, seasonality_mode='additive',
                    holidays=df_holidays, weekly_seasonality=False,
                    **best_params)
my_model.add_seasonality(name='weekly_on_winter', period = 7, fourier_order=10, condition_name='winter')
my_model.add_seasonality(name='weekly_on_summer', period = 7, fourier_order=10, condition_name='summer')
my_model.add_regressor(name='outdoor_temp')
my_model.add_regressor(name='pred_24h_outdoor_temp')
my_model.add_regressor(name='direct_solar_W_m2')
my_model.add_regressor(name='pred_24h_direct_solar_W_m2')

my_model.fit(df)
forecast = my_model.predict(y_test)
forecast
# forecast = my_model.predict(future_dates)
fig = my_model.plot(forecast, uncertainty=True)

# %%
print(f"Mean Absolute Error = {mean_absolute_error(y_test['y'], forecast['yhat']).round(3)}")
print(f"Mean Squared Error = {mean_squared_error(y_test['y'], forecast['yhat']).round(3)}")
