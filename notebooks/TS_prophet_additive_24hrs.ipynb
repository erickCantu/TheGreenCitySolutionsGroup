# %% [markdown]
# # TS Prophet
# ## Data split in training and test. The last 365 days are the test data.

# %%
from audioop import cross
import itertools
from matplotlib import units
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

from prophet import Prophet
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics
from prophet.plot import add_changepoints_to_plot
from prophet.plot import plot_cross_validation_metric
from prophet.plot import plot_plotly, plot_components_plotly

plt.style.use('fivethirtyeight')

from sklearn.metrics import mean_absolute_error,mean_squared_error

from green_city.utils import metrics_dict, datetime2index, index2datetime

# Libraries to reduce Prophet verbose output
import warnings
import logging
import os

# %matplotlib inline

# %%
## MLFLOW ##
import mlflow
from green_city.mlflow_config import get_mlflow_config

flow_conf = get_mlflow_config()
tracking_uri = flow_conf["TRACKING_URI"]
mlflow.set_tracking_uri(flow_conf["TRACKING_URI"])
mlflow.set_experiment(flow_conf["EXPERIMENT_NAME"]);

# %%
def is_winter_season(ds):
    """Classifies the dates into Winter or Summer

    Args:
        ds (datetime series): A Pandas datetime series
    """
    date = pd.to_datetime(ds)
    return(date.month < 4 or date.month > 9)

# %%
## DB CONNECTION ##
from sqlalchemy import create_engine
from decouple import Config, RepositoryEnv

config = Config(RepositoryEnv("../.db_credentials"))

db_connection_credentials = {
    "database": config('POSTGRES_DB'),
    "user": config('POSTGRES_USER'),
    "password": config('POSTGRES_PASSWORD'),
    "host": config('POSTGRES_HOST'),
    "port": config('POSTGRES_PORT'),
}
DB_STRING = "postgresql://{user}:{password}@{host}:{port}/{database}".format(**db_connection_credentials)
db = create_engine(DB_STRING)

# %% [markdown]
# ### Load data and feature engineering

# %%
building = 5
# Load data
df_building = pd.read_csv(f"../data/preprocessed/Building_{building}.csv").astype({'datetime': 'datetime64'})#.set_index('datetime')

# %%
# df_building['net_load_kWh'].plot()

# %%
sns.histplot(df_building['net_load_kWh'], bins=30)

# %%
df_building = df_building.rename(columns={'datetime':'ds',
                                    'net_load_kW':'y'})
# df.head(5)

# %%
df_building['winter'] = df_building['ds'].apply(is_winter_season)
df_building['summer'] = ~df_building['ds'].apply(is_winter_season)

# %%
df_holiday = df_building[['ds','holiday']].query('holiday')
df_holiday['holiday'] = 'Holiday'
# df_holiday

## In the development stage, it was explored to add the workday as part of the  ##
## seasonality. It did not had an effect. Including the holiday did.            ##
# df_workday = df[['ds','workday']].query('workday')
# df_workday['holiday'] = 'Workday'
# df_workday = df_workday.drop('workday', axis=1)

# df_holidays = pd.concat([df_holiday, df_workday], ignore_index=True)

# %%
pred_indices = [32135, 33311, 26478, 33357, 30387, 30794, 31800, 28783]
# pred_indices = [32135]

# %% [markdown]
# ## Prophet model. Full data

# %%
my_model_full = Prophet(interval_width=0.95, seasonality_mode='additive')
my_model_full.fit(df_building)

# %%
future_dates = my_model_full.make_future_dataframe(periods = 365)
forecast = my_model_full.predict(future_dates)

# %%
fig = my_model_full.plot(forecast, uncertainty=True, plot_cap=False)
ax = fig.gca()
ax.set_xlim(pd.to_datetime(['2008-01-02', '2009-01-01']))

# %%
sns.pointplot(x = 'ds', y='y', data=df_building[:24*365])
# sns.lineplot(x = 'ds', y='yhat', data=forecast[:24*365])

# %% [markdown]
# ## Prophet simple model. Three years training

# %% [markdown]
# ### Split data in training and test data

# %%
df_simple_model_train = df_building[:365*3*24]
df_simple_model_test = df_building[365*3*24:]

# %% [markdown]
# ### Simple Prophed model. Specify 95% of uncertainty and additive model. (Default 80% and additive model)

# %%
my_model_simple = Prophet(interval_width = 0.95, seasonality_mode="additive")

# %%
my_model_simple.fit(df_simple_model_train)

# %%
for index in pred_indices:
    with mlflow.start_run(run_name='Prophet Simple Model') as r:
        # print(r.info.run_id)
        ### Predict ##
        # my_model_simple.fit(df.loc[:index])
        df_future = df_building.copy().loc[index+1:index+24]
        df_forecast = my_model_simple.predict(df_future)
        df_forecast.index = df_future.index
        df_forecast.index.name = 'id'
        df_forecast['error'] = df_future.y - df_forecast.yhat
        df_forecast = df_forecast[['yhat', 'error']]
        
        ## Evaluate ##
        metrics = metrics_dict(df_future.y, df_forecast.yhat, ["mae", "mse", "r2_score"])
        print("mae: {mae}, mse: {mse}, r2: {r2_score}".format(**metrics))
        mlflow.log_metrics(metrics)

        ## Parameters log ##
        params = {
            'building_nr': building,
            'datetime':index2datetime(index)
        }
        mlflow.log_params(params)

        forecasts = df_forecast[['yhat']].assign(run_id = r.info.run_id).rename(columns={"yhat": "prediction"})
        # print(forecasts.head())
        # forecasts.to_sql("forecast", con=db, if_exists="append")

# %% [markdown]
# ## Optimize modeling

# %%
def my_prophet_mse(df, all_params):
    """Determine the best hyper parameters for a Prophet model.
    It uses a base Prophet model. 

    Args:
        df (dataframe): A pandas dataframe with the required Prophet structure
        all_params (list of dictionaries): A list of dictionaries with the parameters definition. 

    Returns:
        best_params: a list with the best parameters
        tuning_results: A dataframe with the mse and rmse evaluation of the parameters combinations
    """
    warnings.simplefilter("ignore", DeprecationWarning)
    warnings.simplefilter("ignore", FutureWarning)
    logging.getLogger('prophet').setLevel(logging.ERROR) #Notice that i had modified the name from 'fbprophet' to just 'prophet'
    mses = []
    rmses = []
    for params in all_params:
        m = Prophet(**params)
        m.fit(df)
        df_cv = cross_validation(m, horizon='180 days', parallel='processes')
        df_p = performance_metrics(df_cv, rolling_window=1)
        mses.append(df_p['mse'].values[0])
        rmses.append(df_p['rmse'].values[0])
    tuning_results = pd.DataFrame(all_params)
    tuning_results['mse'] = mses
    tuning_results['rmse'] = rmses
    print(tuning_results)
    best_params=all_params[np.argmin(mses)]
    print(best_params)
    return best_params, tuning_results

# %%
# def my_prophet_rmse(df, all_params):
#     # warnings.simplefilter("ignore", DeprecationWarning)
#     # warnings.simplefilter("ignore", FutureWarning)
#     # logging.getLogger('prophet').setLevel(logging.ERROR) #Notice that i had modified the name from 'fbprophet' to just 'prophet'
#     rmses = []
#     for params in all_params:
#         m = Prophet(**params)
#         m.fit(df)
#         df_cv = cross_validation(m, horizon='180 days', parallel='processes')
#         df_p = performance_metrics(df_cv, rolling_window=1)
#         rmses.append(df_p['rmse'].values[0])
#     tuning_results = pd.DataFrame(all_params)
#     tuning_results['rmse'] = rmses
#     print(tuning_results)
#     best_params=all_params[np.argmin(rmses)]
#     print(best_params)
#     return best_params, tuning_results

# %%
def my_best_params(df, best_params):
    """ Fits the best hyper parameters to the Prophet model

    Args:
        df (dataframe): A pandas dataframe to be fitted
        best_params (list): A list with the best parameters to fit. It must be a list of a dictionary.

    Returns:
        my_model: A Prophet fitted model.
    """
    my_model = Prophet(**best_params)
    my_model.fit(df)
    return my_model

# %%
def my_pred_mse(df,model_name, parameters, pred_index):
    """Forecast a specified interval into a Prophet model. 

    Args:
        df (dataframe)    : A pandas dataframe with the form required by Prophet. Must include the training and testing data.
        model_name (str)  : A string with a unique description of the model to evaluate.
        parameters (list) : A list of dictionaries with the parameters definition. 
        pred_index (list) : A list with the indexes of the intervals to predict. ("Test data"). These indexes must exist in the df variable.

    Returns:
        forecasts (dataframe)           : A dataframe with the forecasted values from the interval of interest. 
        ls_best_params (list)           : A list with the best hyperpameters and its evaluation metrics; mse and rsme.
        my_model(fitted Prophet model)  : A fitted prophet model. The model utilized to forecast the data. 
        ls_publish                      : A list with the information to put in mlflow and the SQL server. Includes the forecasts dataframe,
                                          the msa, mse and r2_score.
    """

    ls_best_params = []
    ls_publish = []
    for index in pred_index:
        df_train=df.loc[:index]
        df_future = df.loc[index+1:index+24]
        with mlflow.start_run(run_name=model_name) as r:
            ### Predict ##
            best_params, tuning_results = my_prophet_mse(df_train, all_params=parameters)
            ls_best_params.append([{'index':index}, best_params, tuning_results])
            my_model = my_best_params(df_train, best_params = best_params)
            df_forecast = my_model.predict(df_future)
            df_forecast.index = df_future.index
            df_forecast.index.name = 'id'
            df_forecast['error'] = df_future.y - df_forecast.yhat
            df_forecast = df_forecast[['yhat', 'error']]
            
            ## Evaluate ##
            metrics = metrics_dict(df_future.y, df_forecast.yhat, ["mae", "mse", "r2_score"])
            print(index)
            print("mae: {mae}, mse: {mse}, r2: {r2_score}".format(**metrics))
            print(ls_best_params)
            mlflow.log_metrics(metrics)

            ## Parameters log ##
            params = {
                'building_nr': building,
                'datetime':index2datetime(index)
            }
            mlflow.log_params(params)

            forecasts = df_forecast[['yhat']].assign(run_id = r.info.run_id).rename(columns={"yhat": "prediction"})
            # forecasts.to_sql("forecast", con=db, if_exists="append")
            ls_publish.append([{'index':index,'metrics':metrics, 'params':params, 'forecast':forecasts}])
    return forecasts, ls_best_params, my_model, ls_publish

# %%
# def my_pred_rsme(df,model_name, parameters, pred_index):
#     ls_best_params = []
#     for index in pred_index:
#         with mlflow.start_run(run_name=model_name) as r:
#             ### Predict ##
#             best_params, tuning_results = my_prophet_rmse(df=df.loc[:index], all_params=parameters)
#             ls_best_params.append([{'index':index}, best_params, tuning_results])
#             my_model = my_best_params(df=df.loc[:index], best_params = best_params)
#             df_future = df.loc[index+1:index+24]
#             df_forecast = my_model.predict(df_future)
#             df_forecast.index = df_future.index
#             df_forecast.index.name = 'id'
#             df_forecast['error'] = df_future.y - df_forecast.yhat
#             df_forecast = df_forecast[['yhat', 'error']]
            
#             ## Evaluate ##
#             metrics = metrics_dict(df_future.y, df_forecast.yhat, ["mae", "mse", "r2_score"])
#             print(index)
#             print("mae: {mae}, mse: {mse}, r2: {r2_score}".format(**metrics))
#             print(ls_best_params)
#             mlflow.log_metrics(metrics)

#             ## Parameters log ##
#             params = {
#                 'building_nr': building,
#                 'datetime':index2datetime(index)
#             }
#             mlflow.log_params(params)

#             forecasts = df_forecast[['yhat']].assign(run_id = r.info.run_id).rename(columns={"yhat": "prediction"})
#             # forecasts.to_sql("forecast", con=db, if_exists="append")
#     return forecasts, ls_best_params

# %%
# # Use RMSE for tunning 
# param_grid_simple = {
#     'interval_width': [0.95],
#     'seasonality_mode':['additive'],
#     'changepoint_prior_scale':[0.05],
#     'seasonality_prior_scale':[10.0],
#     'holidays_prior_scale':[0.01]
# }
# all_params = [dict(zip(param_grid_simple.keys(), v)) for v in itertools.product(*param_grid_simple.values())]

# pred_rmse, ls_best_rmse = my_pred_rsme(df=df_building,
#                 model_name='Prophet Simple Model w/Params - Tunning RMSE', 
#                 parameters=all_params,
#                 pred_index=pred_indices)

# %%
# Use MSE for tunning 
param_grid_simple = {
    'interval_width': [0.95],
    'seasonality_mode':['additive'],
    'changepoint_prior_scale':[0.05],
    'seasonality_prior_scale':[10.0],
    'holidays_prior_scale':[0.01],
    'changepoint_range':[0.8]#,0.9]
}
all_params = [dict(zip(param_grid_simple.keys(), v)) for v in itertools.product(*param_grid_simple.values())]

pred_mse_simpleMod_Opt, ls_best_mse_simpleMod_Opt, m_mse_simpleMod_Opt, ls_publish_mse_simpleMod_Opt = my_pred_mse(df = df_building,
                model_name='Prophet Simple Model w/Params - Tunning MSE', 
                parameters=all_params,
                pred_index=pred_indices)
# Out:
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       56653.8    0.00416767       1175.87           1           1      113
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       56676.6    0.00040963       735.747      0.3855     0.03855      235
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299         56682   0.000290279       449.935      0.1605      0.6624      349
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       56687.2     0.0153445       618.011           1           1      463
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       56689.3   0.000194497       194.598      0.7101      0.7101      585
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      567       56690.1   3.26117e-05       139.453   1.385e-07       0.001      703  LS failed, Hessian reset
#      599       56690.4    0.00103864       129.838      0.9735      0.9735      743
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      601       56690.4   2.14116e-05       106.286   2.278e-07       0.001      789  LS failed, Hessian reset
#      633       56690.5   2.02307e-05        90.031   1.335e-07       0.001      868  LS failed, Hessian reset
#      699       56691.3    0.00606856       652.225       0.586       0.586      954
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      710       56691.7   8.59755e-05       365.195   2.116e-07       0.001     1031  LS failed, Hessian reset
#      797       56692.1   3.11795e-05       139.574   3.479e-07       0.001     1184  LS failed, Hessian reset
#      799       56692.1   0.000162873       71.5379           1           1     1186
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      836       56692.1   1.28221e-06       57.9038      0.4594      0.4594     1235
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -376.544
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -456.566
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -415.366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -361.348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -785.861
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -669.122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -385.439
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99         25908    0.00154799       449.623      0.5145      0.5145      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99         29539    0.00331779       333.545      0.1068      0.7615      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       33059.4   0.000717355       766.499      0.1689      0.1689      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       37442.4    0.00659134       1529.05           1           1      118
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       25914.5   0.000250957       88.7125      0.4512      0.4512      250
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       41681.2    0.00366614       183.219           1           1      115
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       45446.8    0.00697966       887.555      0.4251      0.4251      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99         49022    0.00505907       467.067           1           1      126
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       29548.4   0.000289225       200.992      0.6669      0.6669      242
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       33068.7     0.0011618       75.5497       2.542      0.2542      257
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       25919.5    0.00149313       138.352      0.6539      0.6539      364
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       37459.8     0.0117026       439.358      0.3268           1      231
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      322       25920.1   0.000120419       215.084   6.612e-07       0.001      439  LS failed, Hessian reset
#      299       29554.1   0.000712719       296.113       0.976       0.976      354
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       41698.5    0.00534748       392.724      0.2027      0.9629      238
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       49043.6    0.00200131       248.935           1           1      234
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       33072.8   2.41452e-05       72.6701      0.5376      0.5376      378
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       25920.5   1.48511e-05       82.4096     0.07611           1      542
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       45476.3   8.48921e-05       316.191   2.814e-07       0.001      284  LS failed, Hessian reset
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       37466.4    0.00143575       486.449           1           1      345
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       29561.4     0.0028678       592.368      0.1769      0.4243      474
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      431       25920.5   0.000147301       123.067   1.373e-06       0.001      625  LS failed, Hessian reset
#      457       25920.6   1.16511e-06       80.0105      0.4182           1      655
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      299       41704.9    0.00088712       260.811       1.161      0.1161      364
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       33075.1     0.0525534       349.536      0.7595      0.1175      512
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       29564.8   0.000483585       115.117           1           1      593
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       49054.8    0.00480464       386.098           1           1      341
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       37471.3   0.000226399       349.503      0.8395      0.8395      464
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       45482.6    0.00030946       96.8939           1           1      403
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      510       29564.8   0.000402421       105.317   5.929e-06       0.001      643  LS failed, Hessian reset
#      403       33075.1   9.66517e-05       231.341    6.95e-07       0.001      573  LS failed, Hessian reset
#      331       41705.8   6.43221e-05       216.713   2.154e-07       0.001      445  LS failed, Hessian reset
#      410       37471.5   5.49455e-05       172.322   3.024e-07       0.001      510  LS failed, Hessian reset
#      349       41706.1    6.5915e-05       174.028   8.413e-07       0.001      509  LS failed, Hessian reset
#      556       29565.1   7.44735e-05       177.293   2.936e-07       0.001      749  LS failed, Hessian reset
#      462       37472.3   0.000425057       219.873   1.009e-06       0.001      617  LS failed, Hessian reset
#      482       33076.5   0.000320132         335.8   1.664e-06       0.001      711  LS failed, Hessian reset
#      399       49065.2    0.00196401       269.341      0.1731      0.5561      468
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       33076.6   0.000238572        128.09           1           1      729
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       29565.6    0.00095912       91.6155      0.3703           1      806
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399         41707    0.00768167       316.949           1           1      567
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       45486.6    0.00318526       218.939           1           1      519
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       37472.7   0.000232815       122.455           1           1      663
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      608       29565.6   5.06674e-05       127.587   4.712e-07       0.001      858  LS failed, Hessian reset
#      533       37472.7   3.06199e-06       68.9435           1           1      711
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      599       33077.2   0.000659865       72.3819           1           1      849
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      467         41708   8.39141e-05       253.252   4.188e-07       0.001      689  LS failed, Hessian reset
#      688       29565.9   7.39443e-05       177.893   4.538e-07       0.001     1005  LS failed, Hessian reset
#      499       45490.6    0.00267749       250.568           1           1      638
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       49068.4   0.000574397       274.915      0.8487      0.8487      587
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699         29566   0.000270038       108.865      0.5986      0.5986     1017
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      621       33077.3   3.36741e-05       98.1095   2.919e-07       0.001      919  LS failed, Hessian reset
#      499       41708.3   8.11481e-06       77.1951      0.1874      0.6229      731
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      504       41708.3    1.1506e-06       71.5388     0.04425           1      740
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      653       33077.3    2.8176e-06       68.7364      0.1739      0.1739      956
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      763       29566.2   6.32327e-05       154.439   6.995e-07       0.001     1138  LS failed, Hessian reset
#      799       29566.2   6.19456e-05       96.6823      0.2757           1     1185
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       45491.3    0.00251596       284.367           1           1      765
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       49071.3    0.00226414       503.272      0.3542           1      706
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      801       29566.2   1.98378e-05       75.0736   2.135e-07       0.001     1230  LS failed, Hessian reset
#      810       29566.2   1.54878e-06       57.2051     0.07296           1     1242
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      699       45492.4   0.000181827       104.296       2.259      0.6186      891
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       49076.4    0.00169816       199.769      0.1767           1      827
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       49077.3     0.0010928       305.047      0.8304      0.8304      939
#      787         45493   2.68479e-05        107.16   1.834e-07       0.001     1036  LS failed, Hessian reset
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799         45493   0.000502299       162.225           1           1     1050
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       49079.5    0.00163593       299.293     0.07762      0.6553     1047
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      886       45493.5   9.56122e-05       200.621   1.149e-06       0.001     1196  LS failed, Hessian reset
#      899       45493.5   6.69306e-05       73.9569      0.8459      0.8459     1209
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      960       45493.6   1.88523e-06       63.3065       0.691       0.691     1292
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      999       49080.9   0.000126243       91.4552           1           1     1175
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1048         49081   3.91774e-06       85.9122      0.2689           1     1236
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#    interval_width seasonality_mode  changepoint_prior_scale  \
# 0            0.95         additive                     0.05
#
#    seasonality_prior_scale  holidays_prior_scale  changepoint_range  \
# 0                     10.0                  0.01                0.8
#
#          mse      rmse
# 0  73.974423  8.600839
# {'interval_width': 0.95, 'seasonality_mode': 'additive', 'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 10.0, 'holidays_prior_scale': 0.01, 'changepoint_range': 0.8}
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       56653.8    0.00416767       1175.87           1           1      113
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       56676.6    0.00040963       735.747      0.3855     0.03855      235
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299         56682   0.000290279       449.935      0.1605      0.6624      349
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       56687.2     0.0153445       618.011           1           1      463
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       56689.3   0.000194497       194.598      0.7101      0.7101      585
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      567       56690.1   3.26117e-05       139.453   1.385e-07       0.001      703  LS failed, Hessian reset
#      599       56690.4    0.00103864       129.838      0.9735      0.9735      743
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      601       56690.4   2.14116e-05       106.286   2.278e-07       0.001      789  LS failed, Hessian reset
#      633       56690.5   2.02307e-05        90.031   1.335e-07       0.001      868  LS failed, Hessian reset
#      699       56691.3    0.00606856       652.225       0.586       0.586      954
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      710       56691.7   8.59755e-05       365.195   2.116e-07       0.001     1031  LS failed, Hessian reset
#      797       56692.1   3.11795e-05       139.574   3.479e-07       0.001     1184  LS failed, Hessian reset
#      799       56692.1   0.000162873       71.5379           1           1     1186
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      836       56692.1   1.28221e-06       57.9038      0.4594      0.4594     1235
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 32135
# mae: 4.269368426358877, mse: 25.22000887476217, r2: 0.6676792672643503
# [[{'index': 32135}, {'interval_width': 0.95, 'seasonality_mode': 'additive', 'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 10.0, 'holidays_prior_scale': 0.01, 'changepoint_range': 0.8},    interval_width seasonality_mode  changepoint_prior_scale  \
# 0            0.95         additive                     0.05
#
#    seasonality_prior_scale  holidays_prior_scale  changepoint_range  \
# 0                     10.0                  0.01                0.8
#
#          mse      rmse
# 0  73.974423  8.600839  ]]

# %%
ls_best_mse_simpleMod_Opt
# Out:
# [[{'index': 32135},
#   {'interval_width': 0.95,
#    'seasonality_mode': 'additive',
#    'changepoint_prior_scale': 0.05,
#    'seasonality_prior_scale': 10.0,
#    'holidays_prior_scale': 0.01,
#    'changepoint_range': 0.8},
#      interval_width seasonality_mode  changepoint_prior_scale  \
#   0            0.95         additive                     0.05
#
#      seasonality_prior_scale  holidays_prior_scale  changepoint_range  \
#   0                     10.0                  0.01                0.8
#
#            mse      rmse
#   0  73.974423  8.600839  ]]

# %% [markdown]
# ### Parameters that can be tuned
#
# **changepoint_prior_scale**: This is probably the most impactful parameter. It determines the flexibility of the trend, and in particular how much the trend changes at the trend changepoints. As described in this documentation, if it is too small, the trend will be underfit and variance that should have been modeled with trend changes will instead end up being handled with the noise term. If it is too large, the trend will overfit and in the most extreme case you can end up with the trend capturing yearly seasonality. The default of 0.05 works for many time series, but this could be tuned; a range of [0.001, 0.5] would likely be about right. Parameters like this (regularization penalties; this is effectively a lasso penalty) are often tuned on a log scale.
#
# **seasonality_prior_scale**: This parameter controls the flexibility of the seasonality. Similarly, a large value allows the seasonality to fit large fluctuations, a small value shrinks the magnitude of the seasonality. The default is 10., which applies basically no regularization. That is because we very rarely see overfitting here (there’s inherent regularization with the fact that it is being modeled with a truncated Fourier series, so it’s essentially low-pass filtered). A reasonable range for tuning it would probably be [0.01, 10]; when set to 0.01 you should find that the magnitude of seasonality is forced to be very small. This likely also makes sense on a log scale, since it is effectively an L2 penalty like in ridge regression.
#
# **holidays_prior_scale**: This controls flexibility to fit holiday effects. Similar to seasonality_prior_scale, it defaults to 10.0 which applies basically no regularization, since we usually have multiple observations of holidays and can do a good job of estimating their effects. This could also be tuned on a range of [0.01, 10] as with seasonality_prior_scale.
#
# **seasonality_mode**: Options are ['additive', 'multiplicative']. Default is 'additive', but many business time series will have multiplicative seasonality. This is best identified just from looking at the time series and seeing if the magnitude of seasonal fluctuations grows with the magnitude of the time series (see the documentation here on multiplicative seasonality), but when that isn’t possible, it could be tuned.

# %%
# # Parameter optimization. Tunning CV with RMSE 
# param_grid = {
#     'interval_width': [0.95],
#     'seasonality_mode':['additive'],
#     'changepoint_prior_scale':[0.0001, 0.01, 0.05, 0.1, 0.5], #Parameters like this (regularization penalties; this is effectively a lasso penalty) are often tuned on a log scale.
#     'seasonality_prior_scale':[0.01, 0.1, 1.0, 10.0], #This likely also makes sense on a log scale, since it is effectively an L2 penalty like in ridge regression.
#     'holidays_prior_scale':[0.01, 0.1, 1.0, 10.0],
#     'changepoint_range':[0.8,0.9]
# }
# all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

# pred_rmse, ls_best_rmse = my_pred_rsme(df = df_building,
#         model_name='Prophet Simple Model Optimized Parameters - Tunning with RMSE', 
#         parameters=all_params,
#         pred_index=pred_indices)

# %%
# Parameter optimization. Tunning CV with MSE 
param_grid = {
    'interval_width': [0.95],
    'seasonality_mode':['additive'],
    'changepoint_prior_scale':[0.0001, 0.01, 0.05, 0.1, 0.5], #Parameters like this (regularization penalties; this is effectively a lasso penalty) are often tuned on a log scale.
    'seasonality_prior_scale':[0.01, 0.1, 1.0, 10.0], #This likely also makes sense on a log scale, since it is effectively an L2 penalty like in ridge regression.
    'holidays_prior_scale':[0.01, 0.1, 1.0, 10.0],
    'changepoint_range':[0.8,0.9]
}
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

pred_mse_simpleMod_Opt, ls_best_mse_simpleMod_Opt, m_mse_simpleMod_Opt, ls_publish_mse_simpleMod_Opt = my_pred_mse(df = df_building,
        model_name='Prophet Simple Model Optimized Parameters - Tunning with MSE', 
        parameters=all_params,
        pred_index=pred_indices)

# %% [markdown]
# ### Comparison between RMSE and MSE for CV assessment in Hyperparmeter selection

# %% [markdown]
# ### Add holidays

# %%
param_grid = {
    'interval_width': [0.95],
    'seasonality_mode':['additive'],
    'changepoint_prior_scale':[0.0001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale':[0.01, 0.1, 1.0, 10.0],
    'holidays':[df_holiday],
    'holidays_prior_scale':[0.01, 0.1, 1.0, 10.0],
    'changepoint_range':[0.8,0.9]
}
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

pred_mse_WkMod_Opt_holidays, ls_best_mse_WkMod_Opt_holidays, m_best_mse_WkMod_Opt_holidays, ls_publish_best_mse_WkMod_Opt_holidays = my_pred_mse(df = df_building,
        model_name='Prophet Holidays-Optimized-Parameters - Tunning with MSE', 
        parameters=all_params,
        pred_index=pred_indices)

# %% [markdown]
# ### Assume different weekly sesonalities. Summer vs Winter

# %%
def my_prophet_mse(df, all_params):
    """Determine the best hyper parameter models.
    It specifies a weekly seasonality based in two different seasons; Winter and Summer. Prophet model. 

    Args:
        df (dataframe): A pandas dataframe with the required Prophet structure
        all_params (list of dictionaries): A list of dictionaries with the parameters definition. 

    Returns:
        best_params: a list with the best parameters
        tuning_results: A dataframe with the mse and rmse evaluation of the parameters combinations
    """
    warnings.simplefilter("ignore", DeprecationWarning)
    warnings.simplefilter("ignore", FutureWarning)
    logging.getLogger('prophet').setLevel(logging.ERROR) #Notice that i had modified the name from 'fbprophet' to just 'prophet'
    mses = []
    rmses = []
    for params in all_params:
        m = Prophet(**params,
        weekly_seasonality=False
        )
        m.add_seasonality(name='weekly_on_winter', period = 7, fourier_order= 10, condition_name='winter')
        m.add_seasonality(name='weekly_on_summer', period = 7, fourier_order= 10, condition_name='summer')
        m.fit(df)
        df_cv = cross_validation(m, horizon='180 days', parallel='processes')
        df_p = performance_metrics(df_cv, rolling_window=1)
        mses.append(df_p['mse'].values[0])
        rmses.append(df_p['rmse'].values[0])
    tuning_results = pd.DataFrame(all_params)
    tuning_results['mse'] = mses
    tuning_results['rmse'] = rmses
    print(tuning_results)
    best_params=all_params[np.argmin(rmses)]
    print(best_params)
    return best_params, tuning_results

# %%
param_grid = {
    'interval_width': [0.95],
    'seasonality_mode':['additive'],
    'changepoint_prior_scale':[0.0001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale':[0.01, 0.1, 1.0, 10.0],
    'holidays':[df_holiday],
    'holidays_prior_scale':[0.01, 0.1, 1.0, 10.0],
    'changepoint_range':[0.8,0.9]
}
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

pred_mse_WkSeasMod_Opt, ls_best_mse_WkSeasMod_Opt, m_best_mse_WkSeasMod_Opt, ls_publish_best_mse_WkSeasMod_Opt = my_pred_mse(df=df_building,
        model_name='Prophet Holidays-Winter/Summer-Optimized-Parameters - Tunning with MSE', 
        parameters=all_params,
        pred_index=pred_indices)

# %% [markdown]
# ### Add outdoor temperature and direct solar energy as additional regressor. Include 24h forecast for each feature too.
# ### The temperature and solar energy data is in the original dataset.

# %%
def my_prophet_mse(df, all_params):
    """Determine the best hyper parameter models.
    It specifies a weekly seasonality based in two different seasons; Winter and Summer. 
    It specifies additional regressors to the Prophet model. 

    Args:
        df (dataframe): A pandas dataframe with the required Prophet structure
        all_params (list of dictionaries): A list of dictionaries with the parameters definition. 

    Returns:
        best_params: a list with the best parameters
        tuning_results: A dataframe with the mse and rmse evaluation of the parameters combinations
    """
    warnings.simplefilter("ignore", DeprecationWarning)
    warnings.simplefilter("ignore", FutureWarning)
    logging.getLogger('prophet').setLevel(logging.ERROR) #Notice that i had modified the name from 'fbprophet' to just 'prophet'
    mses = []
    rmses = []
    for params in all_params:
        m = Prophet(**params,
        weekly_seasonality=False
        )
        m.add_seasonality(name='weekly_on_winter', period = 7, fourier_order= 10, condition_name='winter')
        m.add_seasonality(name='weekly_on_summer', period = 7, fourier_order= 10, condition_name='summer')
        m.add_regressor(name='outdoor_temp')
        m.add_regressor(name='pred_24h_outdoor_temp')
        m.add_regressor(name='direct_solar_W_m2')
        m.add_regressor(name='pred_24h_direct_solar_W_m2')
        m.fit(df)
        df_cv = cross_validation(m, horizon='180 days', parallel='processes')
        df_p = performance_metrics(df_cv, rolling_window=1)
        mses.append(df_p['mse'].values[0])
        rmses.append(df_p['rmse'].values[0])
    tuning_results = pd.DataFrame(all_params)
    tuning_results['mse'] = mses
    tuning_results['rmse'] = rmses
    print(tuning_results)
    best_params=all_params[np.argmin(rmses)]
    print(best_params)
    return best_params, tuning_results

# %%
param_grid = {
    'interval_width': [0.95],
    'seasonality_mode':['additive'],
    'changepoint_prior_scale':[0.0001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale':[0.01, 0.1, 1.0, 10.0],
    'holidays':[df_holiday],
    'holidays_prior_scale':[0.01, 0.1, 1.0, 10.0],
    'changepoint_range':[0.8,0.9]
}
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

pred_mse_best_mse_RegMod_Opt, ls_best_mse_best_mse_RegMod_Opt, m_mse_best_mse_RegMod_Opt, ls_publish_mse_best_mse_RegMod_Opt = my_pred_mse(df=df_building,
        model_name='Prophet Holidays-Winter/Summer-Regressors-Optimized-Parameters - Tunning with MSE', 
        parameters=all_params,
        pred_index=pred_indices)
# Out:
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       62253.3   7.66563e-06       51099.3       0.874       0.874      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      121       62257.8   5.04082e-05       50316.9   1.009e-09       0.001      210  LS failed, Hessian reset
#      159       62260.6   2.21114e-06       50716.3    4.32e-11       0.001      306  LS failed, Hessian reset
#      193       62260.7   8.40992e-09       49595.5       0.795       0.795      348
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -415.366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -376.544
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -385.439
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -456.566
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -361.348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -669.122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -785.861
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       32352.3   2.35564e-07         49371      0.6052      0.6052      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       48         36400    0.00134161         52092   2.717e-08       0.001      122  LS failed, Hessian reset
#       98       28271.8   3.41336e-05         47772   7.777e-10       0.001      170  LS failed, Hessian reset
#       99       28272.3   1.13663e-05         45614           1           1      171
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      116       32432.1   0.000660665         54568    1.31e-08       0.001      217  LS failed, Hessian reset
#       99       36458.4   2.68104e-05       43859.9      0.9886      0.9886      195
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       49893.8   5.14991e-06         48051           1           1      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      161       28274.1   5.07137e-09       50952.8       0.171       0.171      252
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       98       41200.2   4.75618e-07       50626.7   8.906e-12       0.001      169  LS failed, Hessian reset
#       99       41200.2   2.53788e-07       49390.7           1           1      170
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       87       45765.3   0.000708736       48063.9   1.442e-08       0.001      162  LS failed, Hessian reset
#       62       53908.5   3.12369e-05       49895.6    6.08e-10       0.001      130  LS failed, Hessian reset
#       99         45817   6.29889e-05       47425.2      0.4043           1      177
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      115       41200.3   3.77421e-09       49661.7      0.3209      0.3209      192
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      177       32469.6   5.98272e-09       50106.6      0.1586      0.1586      297
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      102       49893.8   3.21349e-06       50496.4   6.711e-11       0.001      177  LS failed, Hessian reset
#      143       36471.1   8.30557e-05       41825.9   1.471e-09       0.001      305  LS failed, Hessian reset
#      131         49894   5.70761e-09         44703      0.3515           1      214
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       89       53912.6    1.7439e-05       51376.8   3.557e-10       0.001      202  LS failed, Hessian reset
#      164       45823.5   8.93819e-09       48319.8      0.2576      0.2576      260
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       53913.5   4.22884e-06       49467.1      0.8046      0.8046      213
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      190       36473.6   9.98448e-09         49477           1           1      364
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      128       53914.3   9.74226e-07       49991.3   1.937e-11       0.001      300  LS failed, Hessian reset
#      147       53914.4   5.26039e-09       49265.1      0.5623      0.5623      322
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       96       62317.9   8.11884e-07       51061.8   1.604e-11       0.001      173  LS failed, Hessian reset
#       99       62317.9   2.13001e-07         49164       0.529       0.529      176
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      119         62318   6.24526e-09       50026.7      0.4146           1      203
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -376.544
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -415.366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -361.348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -456.566
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -385.439
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -669.122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -785.861
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       93       28194.5   8.13932e-09       48642.8      0.6888      0.6888      123
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       83       32438.8   0.000257936       52807.6   4.753e-09       0.001      158  LS failed, Hessian reset
#       99       32447.7   5.32977e-06       46724.4      0.2239           1      178
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       41223.8   2.75203e-05       48266.3      0.6931      0.6931      130
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       36446.1   5.05247e-07       49487.5           1           1      130
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       45633.5   1.31693e-06       48520.9      0.5224      0.5224      123
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      125       32447.9   6.73296e-09       47381.4      0.2321      0.2321      209
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      140       41226.7   2.10964e-09       53133.6     0.09829     0.09829      185
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       54       53911.6   0.000193419       50671.2    3.83e-09       0.001      117  LS failed, Hessian reset
#       78       49812.5   0.000199604       50602.9   4.026e-09       0.001      147  LS failed, Hessian reset
#      121       36451.9   0.000101653       51536.6   2.017e-09       0.001      203  LS failed, Hessian reset
#      116       45634.1   4.49546e-06       49875.1   9.099e-11       0.001      192  LS failed, Hessian reset
#       99         49834    1.6816e-05       51557.3      0.2094           1      172
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      155       36454.9   8.72011e-09       49383.4      0.4846      0.4846      243
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       96       53919.5   6.61739e-09       52058.5      0.4755      0.4755      172
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      149       45634.2   9.17017e-09       48906.3      0.1707           1      234
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      130       49834.9   7.33658e-09       50099.2      0.3284      0.3284      215
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       62403.1   6.14766e-08       47859.6      0.9704      0.9704      130
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      104       62403.1   7.84135e-09       49775.2      0.5428      0.5428      135
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -376.544
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -456.566
# Initial log joint probability = -415.366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -361.348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -385.439
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -669.122
# Initial log joint probability = -785.861
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99         28316   1.07341e-05         44247      0.4319      0.4319      124
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       71         32322   4.48096e-06       50684.7    8.89e-11       0.001      146  LS failed, Hessian reset
#       99       36493.4   1.15863e-06       46048.1           1           1      132
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      115       28319.9   2.07881e-05       44132.1   4.048e-10       0.001      186  LS failed, Hessian reset
#       99       41260.2   6.68953e-07       47953.7           1           1      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       96       32322.2   8.98683e-09       49490.5      0.6843      0.6843      176
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      119       36493.4   6.84594e-09       43292.4      0.2989      0.2989      157
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       73       53911.5   6.37792e-09       49644.1      0.5089      0.5089      100
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      116       41260.2   7.66712e-09       47318.4      0.3908           1      154
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       94       49951.3   2.89154e-09       49366.3      0.2039      0.2039      128
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       86       45780.2   0.000779634       43097.2   1.958e-08       0.001      160  LS failed, Hessian reset
#      182         28321   3.85909e-06       48131.2   7.456e-11       0.001      314  LS failed, Hessian reset
#       99       45843.2   7.06828e-05       42278.2      0.4419      0.4419      174
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       28321.1   3.73468e-08       47153.2      0.5307      0.5307      333
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      206       28321.1   9.88626e-09       48276.5           1           1      341
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      144       45859.7    7.0025e-09       42637.3      0.5071      0.5071      229
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       62359.4   1.18858e-06       52419.8      0.6714      0.6714      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      118       62359.4   9.33551e-09       47471.9      0.6903      0.6903      154
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -376.544
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -415.366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -456.566
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -385.439
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -669.122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -361.348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -785.861
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       54         32475   0.000115165       49833.2   2.388e-09       0.001      112  LS failed, Hessian reset
#       99       28310.2   7.48455e-07         44799      0.6073      0.6073      137
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      126       28310.3   5.34301e-09       43920.3      0.1819      0.1819      173
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       32479.2   1.91272e-06       49534.4           1           1      169
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       52       49729.4    0.00178682       47647.9   3.534e-08       0.001      109  LS failed, Hessian reset
#       99       41250.6   1.93975e-07       50044.8           1           1      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       45833.4   4.59271e-08       52690.4      0.1793      0.1793      123
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      111       41250.6   5.94603e-09       48334.4      0.5368      0.5368      143
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       98       36489.9   9.57915e-08         51267   1.905e-12       0.001      179  LS failed, Hessian reset
#       99       36489.9     4.585e-08       47955.9           1           1      180
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      106       36489.9   1.84622e-09       50654.8      0.1969      0.1969      188
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      122       32479.5   5.50672e-07       45451.6   1.044e-11       0.001      242  LS failed, Hessian reset
#      114       45833.4    6.2333e-09       49465.8      0.6142      0.6142      142
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      139       32479.5   4.77893e-09       46595.5      0.4694      0.4694      262
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       49807.3    0.00010847       48976.2      0.4302           1      169
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       83       53912.1   1.09897e-07         49627    2.14e-12       0.001      171  LS failed, Hessian reset
#       86       53912.1   7.60956e-09       50063.9       0.382       0.382      175
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      128       49808.3    8.1721e-09       48685.2      0.5306      0.5306      205
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       62352.2   1.00697e-06       48778.2           1           1      136
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      115       62355.3   3.13884e-05       47968.6   6.161e-10       0.001      200  LS failed, Hessian reset
#      167       62356.7   6.38001e-09       48448.6      0.4882      0.4882      265
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -376.544
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -415.366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -456.566
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -361.348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -385.439
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -669.122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -785.861
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       28340.1   3.22738e-07       49684.3      0.2543      0.2543      135
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       73       32189.3   1.27135e-06       50653.9   2.645e-11       0.001      141  LS failed, Hessian reset
#       92       36482.5   6.96161e-09       44802.7      0.3004           1      123
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       41250.2   6.00216e-08       49343.8           1           1      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       32189.4   1.35329e-07       50925.2           1           1      172
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      111       41250.3   7.35162e-09       45042.5      0.5139      0.5139      142
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      137       28341.3   1.04666e-06       45774.2   2.028e-11       0.001      237  LS failed, Hessian reset
#       71       45855.3   0.000814843       49213.4   1.651e-08       0.001      134  LS failed, Hessian reset
#      158       28341.4   8.10605e-09       52222.8      0.5496      0.5496      264
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       93       49953.3   6.71592e-09       50757.4     0.09485     0.09485      134
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      104       32189.4   1.21038e-07         48562   2.434e-12       0.001      243  LS failed, Hessian reset
#      110       32189.4   5.04564e-09       51558.8      0.3655      0.3655      251
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       45887.8   4.06462e-06       46974.2      0.3509      0.9142      168
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       74         53940   2.22252e-07       49691.6   4.474e-12       0.001      150  LS failed, Hessian reset
#       87         53940   9.55239e-09       50899.8           1           1      167
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      131       45894.2   4.32789e-05       49768.2   8.544e-10       0.001      250  LS failed, Hessian reset
#      179       45899.3   4.60097e-06       49669.7   9.072e-11       0.001      351  LS failed, Hessian reset
#      199       45899.7   8.34314e-08       49512.6           1           1      378
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      213       45899.7   1.35224e-07       50546.2   2.627e-12       0.001      440  LS failed, Hessian reset
#      221       45899.7   8.94587e-09       49230.8       0.407           1      451
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       62393.4   5.53271e-07       49647.6       1.091      0.2831      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      113       62393.4    5.3784e-09       49348.1      0.1562      0.1562      147
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -376.544
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -456.566
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -361.348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -415.366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -669.122
# Initial log joint probability = -385.439
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -785.861
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       28345.4    3.1483e-06       50356.1      0.2346      0.2346      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       64       32477.3   0.000279829       50323.1   5.562e-09       0.001      120  LS failed, Hessian reset
#      128         28346   6.17567e-09       50043.2      0.6675      0.6675      169
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99         36514   2.33985e-08       47225.8           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       97       41234.7   5.26974e-09       49849.2      0.4622      0.4622      125
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       32490.4   3.74387e-07       50384.1       1.703      0.3727      167
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       45       49733.7    0.00111278       57994.8   2.239e-08       0.001      101  LS failed, Hessian reset
#      122         36514    8.0079e-09       46307.9       0.539       0.539      158
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       45834.8   1.60584e-06       47927.1      0.5164      0.5164      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       78       53930.3   9.49922e-09       50249.5      0.4297           1      107
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      110       32490.5    6.5553e-07       52924.9   1.476e-11       0.001      221  LS failed, Hessian reset
#      132         45835   4.75335e-09       45751.9      0.1602      0.1602      160
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      134       32490.5   6.56609e-09       49360.1      0.6399      0.6399      251
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       49816.7   5.91837e-07       48690.4      0.7032      0.7032      163
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      115       49817.6   9.70158e-06       49570.2   1.973e-10       0.001      221  LS failed, Hessian reset
#      149       49817.9   8.00817e-09       46813.8      0.3216      0.3216      260
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       91       62303.2   0.000102517         48424    1.96e-09       0.001      154  LS failed, Hessian reset
#       99       62307.6   1.49612e-05       50038.7      0.7344      0.7344      164
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      154       62308.7   3.90667e-07       52047.5   7.833e-12       0.001      276  LS failed, Hessian reset
#      160       62308.7   7.11055e-09       48976.2      0.1296      0.1296      284
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -415.366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -376.544
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -456.566
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -385.439
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -361.348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -785.861
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -669.122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       61       28327.6   0.000183556       45246.3   3.846e-09       0.001      116  LS failed, Hessian reset
#       79       32188.5   9.08935e-09       48876.3      0.6603      0.6603      113
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       28336.6   2.55196e-07       47930.9      0.1796           1      172
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       36518.8   2.68942e-05         49050       0.365       0.365      130
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      109       28336.6   9.75769e-09       43302.8      0.4346      0.4346      184
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       41251.7   1.21542e-06       49197.2           1           1      126
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       45750.8    0.00130814       53092.9           1           1      119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       66       53940.2   8.36288e-09       50989.7        0.21        0.21       94
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       58       49948.5   0.000163367       51097.8   3.103e-09       0.001      122  LS failed, Hessian reset
#      106       41251.8   1.20482e-06         47075   2.368e-11       0.001      175  LS failed, Hessian reset
#      103       45782.5    0.00121421         55512   2.697e-08       0.001      172  LS failed, Hessian reset
#      141         36522   1.02651e-07       49574.8   2.044e-12       0.001      231  LS failed, Hessian reset
#      147         36522   9.66625e-09         47758           1           1      238
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      129       41251.9   5.40197e-09       48857.6       0.498       0.498      203
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       95       49954.8   8.17071e-09       49205.6      0.6648      0.6648      166
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      174       45873.2    0.00010191       46669.9   2.126e-09       0.001      300  LS failed, Hessian reset
#      199       45879.3   1.14751e-06         46319      0.2888      0.9738      332
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      214       45879.3    6.4239e-09       48757.6      0.1876      0.1876      354
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       62395.5   4.12859e-06       49932.6           1           1      126
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      100       62395.5   6.06995e-07       51968.9   1.216e-11       0.001      168  LS failed, Hessian reset
#      123       62395.5   2.17594e-09         49000      0.4026      0.4026      195
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -376.544
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -456.566
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -415.366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -361.348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -669.122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -385.439
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -785.861
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       28342.4   0.000270804       49666.1      0.0664           1      126
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       53       32483.8   0.000284555       49661.1   5.626e-09       0.001      107  LS failed, Hessian reset
#       99         36517   1.53506e-05         50236      0.3986      0.3986      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       91       32493.1   4.92503e-09       48042.7      0.2724      0.2724      151
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      131       28345.1   5.52403e-06       49761.6    1.12e-10       0.001      205  LS failed, Hessian reset
#       99       41224.9   1.10364e-07       47498.6      0.2327      0.2327      124
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      150       28345.3   5.00789e-09         51698      0.1557      0.1557      228
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      111         41225   7.98713e-09       43980.5      0.3115      0.3115      141
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       69       53929.9   3.82438e-09       49468.8      0.1602      0.1602       98
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      141       36517.7   6.79573e-09       49344.5       0.207       0.207      179
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       45831.2   5.12534e-05       43795.9      0.1508           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       49819.3   1.40401e-07       44023.2      0.4396      0.4396      135
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      111       49819.4    6.6535e-09       47329.6        0.32        0.32      150
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      132       45834.5   1.09476e-05         50478   2.112e-10       0.001      208  LS failed, Hessian reset
#      192       45836.1   4.72404e-09       49338.3      0.4995      0.4995      287
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       62396.5   8.02651e-09       50385.4      0.3234      0.3234      136
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -376.544
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -361.348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -385.439
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -785.861
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -456.566
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -415.366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -669.122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       28430.8    8.1341e-08       46288.4           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      108       28430.8   5.69318e-09       48644.9      0.5623      0.5623      139
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       96       32579.6   5.08003e-09       49810.1      0.4751      0.4751      127
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       58       36573.4   0.000205851       48578.3   4.276e-09       0.001      115  LS failed, Hessian reset
#       97       41339.5   7.49838e-09       50418.9      0.5232      0.5232      130
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       93       49983.8   2.02068e-09       50297.9      0.1139      0.1139      126
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       82         45812   0.000796222       51946.5   1.756e-08       0.001      151  LS failed, Hessian reset
#       99       36583.3   7.70438e-08       44717.1     0.04356           1      169
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       69       53958.6   1.13806e-06       49793.3   2.316e-11       0.001      136  LS failed, Hessian reset
#       99       45857.7   1.62828e-05         43229      0.7165      0.7165      170
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      127       36583.4   8.21978e-09       45012.9      0.4741      0.4741      205
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       53958.6   1.48483e-08       46386.6      0.8524      0.8524      174
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      100       53958.6   2.99257e-09         44292      0.4201      0.4201      175
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      135       45891.9   6.78046e-05       49733.4    1.33e-09       0.001      265  LS failed, Hessian reset
#      180       45896.5    4.5906e-09       50321.6      0.2407      0.2407      322
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       62440.9   2.56124e-07       50626.6      0.3261      0.3261      135
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      112         62441   3.31154e-09       49576.6      0.2617      0.2617      152
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -376.544
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -415.366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -456.566
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -669.122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -385.439
# Initial log joint probability = -361.348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -785.861
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       66       28397.8   0.000121338       50207.9   2.324e-09       0.001      140  LS failed, Hessian reset
#       99       32561.6   3.94925e-06       51588.1           1           1      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       36591.3   0.000193003       49217.8      0.4461      0.4461      125
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       83       28405.3   1.82034e-05       54454.7   3.455e-10       0.001      201  LS failed, Hessian reset
#       99       28406.4   2.13293e-06         45528      0.1549       0.407      220
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       65       54017.3   9.42534e-09       48070.2      0.2068      0.2068       88
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       41244.6   1.14099e-07       50140.2      0.9679      0.9679      126
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      106       32562.1   1.59909e-06       47317.3   3.188e-11       0.001      179  LS failed, Hessian reset
#      122       28406.5   9.37606e-09       48311.2      0.6192      0.6192      247
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      140       36603.4    6.0178e-09       47862.9      0.4112      0.4112      179
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       45819.2   1.25474e-06       52731.2      0.2823      0.2823      133
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      129       32562.2   2.05461e-09         50535      0.2144      0.2144      208
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       49694.2   1.64995e-08         49655      0.2337      0.2337      140
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      110       41244.6   1.38315e-07       49259.1   2.772e-12       0.001      187  LS failed, Hessian reset
#      107       49694.2    9.6787e-09       47787.2      0.8034      0.8034      149
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      128       45819.5   7.10412e-09       47610.4      0.1652      0.1652      169
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      114       41244.6    6.8764e-09       50828.9      0.2716      0.2716      192
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       62490.2     9.057e-09       49381.3      0.4311      0.4311      135
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -376.544
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -415.366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -456.566
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -785.861
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -361.348
# Initial log joint probability = -669.122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Initial log joint probability = -385.439
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       69       28417.1    0.00040163       55022.8   7.684e-09       0.001      153  LS failed, Hessian reset
#       99       32622.6   7.46085e-06       52304.2           1           1      126
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       89       36614.5    9.1624e-09       48665.5      0.3734      0.3734      112
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       28490.3   0.000129036       48758.3      0.4169           1      187
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       91       41361.7   6.55869e-09       50800.6      0.3231      0.3231      118
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       65         54084   8.38712e-09       50795.2      0.2354      0.2354       91
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      144       28493.4   2.71771e-09       48346.5      0.2441      0.2441      244
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       78       45850.6    0.00186068       51928.1   3.796e-08       0.001      142  LS failed, Hessian reset
#       66       50048.8   0.000192074       50072.3   3.824e-09       0.001      122  LS failed, Hessian reset
#      141       32646.3   2.01074e-06       49719.7    4.03e-11       0.001      219  LS failed, Hessian reset
#      161       32646.4   5.17462e-09       50221.9      0.5122      0.5122      243
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#       99       45933.8   1.67498e-05       46826.7      0.2857           1      169
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       94       50063.2   2.99972e-05       51662.2   6.085e-10       0.001      193  LS failed, Hessian reset
#       99       50063.8   2.45702e-06       49663.4      0.5696      0.5696      199
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      165       45962.8   9.76448e-09       50694.9      0.3694           1      250
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#      123       50065.2   1.24677e-05       51116.1   2.467e-10       0.001      271  LS failed, Hessian reset
#      149       50065.8   7.49742e-09       50723.2      0.3365      0.3365      307
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       90       62490.5   2.48352e-09       50093.1       0.177       0.177      120
# Optimization terminated normally:
# ...
#     2299       32844.8   4.71272e-05       35.6415      0.5847      0.5847     2482
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       54476.9    0.00584451       589.568           1           1     1499
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       36857.6    0.00100878       175.709      0.3823           1     2273
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2114       36857.6   7.68149e-05       18.6152      0.9298      0.9298     2289
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#     2399       32844.9   1.98073e-05       19.5921           1           1     2588
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       41589.4   0.000582691       236.081      0.2639      0.2639     2047
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       46281.2    0.00130513        192.33           1           1     1832
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       50434.8   9.26706e-05       166.091      0.6458      0.6458     1718
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       54477.6   0.000795802       107.406           1           1     1608
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2482       32845.1   9.62531e-06       22.9912   5.256e-07       0.001     2725  LS failed, Hessian reset
#     1999       41590.1   0.000560843       70.8389           1           1     2156
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       32845.1   0.000283314       62.5593           1           1     2745
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       46282.1    0.00256982       212.947           1           1     1937
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       50435.7    0.00106658       92.9695           1           1     1824
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2551       32845.2   1.18374e-05       9.61237           1           1     2799
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#     1599       54478.5   0.000822994       468.434       0.698       0.698     1714
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       41591.6    0.00063326       109.492           1           1     2265
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       46284.6    0.00172077        425.78           1           1     2042
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       50436.3    0.00054634       188.947           1           1     1931
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       41591.7   2.61684e-05       102.651      0.6848      0.6848     2370
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       54479.2    0.00212228       254.714      0.3757           1     1826
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999         46285   0.000523364       81.2327           1           1     2148
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       50437.2     0.0013585       204.382           1           1     2037
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299         41592   0.000435528       110.649           1           1     2479
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       46285.4   6.19367e-05         94.35      0.7267      0.7267     2254
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       54479.7   8.88651e-05       76.4897           1           1     1934
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       50439.2     0.0102221       709.526           1           1     2142
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       41592.5   6.48266e-05       54.8896      0.7753      0.7753     2584
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       46285.7     0.0014201       156.423           1           1     2361
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       41592.7   0.000396537       165.669           1           1     2693
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2228       46285.7   7.16077e-05       17.1876           1           1     2392
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#     1899       54479.9   0.000289515       156.453           1           1     2039
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       50443.4    0.00176763       306.619      0.7525      0.7525     2246
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1950         54480   1.70793e-05       18.4075           1           1     2094
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#     2599       41592.8    0.00104127       45.7576           1           1     2798
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       50445.4     0.0148883       592.056           1           1     2359
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2685       41592.9    0.00011416       10.5127           1           1     2890
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#     2299       50447.7   0.000450507       106.974           1           1     2468
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       50448.6   0.000916214       138.206           1           1     2577
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       50449.2   0.000412418       89.2515           1           1     2684
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       50449.6   0.000203954       59.6173           1           1     2792
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699       50449.9   0.000478257       52.4813           1           1     2903
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       50450.1   9.19496e-05       44.3884           1           1     3011
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2899       50450.5   0.000222188       33.6026           1           1     3122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999       50450.7   0.000188233       87.9393           1           1     3231
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099       50450.8   0.000196447       114.151           1           1     3339
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199       50450.9   8.07718e-05       39.6427           1           1     3444
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3234       50450.9   1.15899e-05       15.1967           1           1     3482
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      interval_width seasonality_mode  changepoint_prior_scale  \
# 0              0.95         additive                   0.0001
# 1              0.95         additive                   0.0001
# 2              0.95         additive                   0.0001
# 3              0.95         additive                   0.0001
# 4              0.95         additive                   0.0001
# ..              ...              ...                      ...
# 123            0.95         additive                   0.5000
# 124            0.95         additive                   0.5000
# 125            0.95         additive                   0.5000
# 126            0.95         additive                   0.5000
# 127            0.95         additive                   0.5000
#
#      seasonality_prior_scale  \
# 0                       0.01
# 1                       0.01
# 2                       0.01
# 3                       0.01
# 4                       0.01
# ..                       ...
# 123                    10.00
# 124                    10.00
# 125                    10.00
# 126                    10.00
# 127                    10.00
#
#                                               holidays  holidays_prior_scale  \
# 0                           ds  holiday
# 0     2008-...                  0.01
# 1                           ds  holiday
# 0     2008-...                  0.01
# 2                           ds  holiday
# 0     2008-...                  0.10
# 3                           ds  holiday
# 0     2008-...                  0.10
# 4                           ds  holiday
# 0     2008-...                  1.00
# ..                                                 ...                   ...
# 123                         ds  holiday
# 0     2008-...                  0.10
# 124                         ds  holiday
# 0     2008-...                  1.00
# 125                         ds  holiday
# 0     2008-...                  1.00
# 126                         ds  holiday
# 0     2008-...                 10.00
# 127                         ds  holiday
# 0     2008-...                 10.00
#
#      changepoint_range         mse       rmse
# 0                  0.8   38.536611   6.207786
# 1                  0.9   39.007330   6.245585
# 2                  0.8   38.428768   6.199094
# 3                  0.9   38.862521   6.233981
# 4                  0.8   38.179507   6.178957
# ..                 ...         ...        ...
# 123                0.9  114.517625  10.701291
# 124                0.8   80.100486   8.949888
# 125                0.9  113.132132  10.636359
# 126                0.8   86.097870   9.278894
# 127                0.9  110.797047  10.526018
#
# [128 rows x 9 columns]
# {'interval_width': 0.95, 'seasonality_mode': 'additive', 'changepoint_prior_scale': 0.0001, 'seasonality_prior_scale': 1.0, 'holidays':                        ds  holiday
# 0     2008-01-02 00:00:00  Holiday
# 1     2008-01-02 01:00:00  Holiday
# 2     2008-01-02 02:00:00  Holiday
# 3     2008-01-02 03:00:00  Holiday
# 4     2008-01-02 04:00:00  Holiday
# ...                   ...      ...
# 34891 2011-12-25 19:00:00  Holiday
# 34892 2011-12-25 20:00:00  Holiday
# 34893 2011-12-25 21:00:00  Holiday
# 34894 2011-12-25 22:00:00  Holiday
# 34895 2011-12-25 23:00:00  Holiday
#
# [960 rows x 2 columns], 'holidays_prior_scale': 0.1, 'changepoint_range': 0.8}
# Initial log joint probability = -566.475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       56181.9   1.90833e-05       57008.2      0.6163      0.6163      134
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      145       56224.6   8.18128e-09       47300.5      0.2259      0.2259      191
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# 32135
# mae: 5.7422959925925285, mse: 49.55838075217169, r2: 0.3469757490357219
# [[{'index': 32135}, {'interval_width': 0.95, 'seasonality_mode': 'additive', 'changepoint_prior_scale': 0.0001, 'seasonality_prior_scale': 1.0, 'holidays':                        ds  holiday
# 0     2008-01-02 00:00:00  Holiday
# 1     2008-01-02 01:00:00  Holiday
# 2     2008-01-02 02:00:00  Holiday
# 3     2008-01-02 03:00:00  Holiday
# 4     2008-01-02 04:00:00  Holiday
# ...                   ...      ...
# 34891 2011-12-25 19:00:00  Holiday
# 34892 2011-12-25 20:00:00  Holiday
# 34893 2011-12-25 21:00:00  Holiday
# 34894 2011-12-25 22:00:00  Holiday
# 34895 2011-12-25 23:00:00  Holiday
#
# [960 rows x 2 columns], 'holidays_prior_scale': 0.1, 'changepoint_range': 0.8},      interval_width seasonality_mode  changepoint_prior_scale  \
# 0              0.95         additive                   0.0001
# 1              0.95         additive                   0.0001
# 2              0.95         additive                   0.0001
# 3              0.95         additive                   0.0001
# 4              0.95         additive                   0.0001
# ..              ...              ...                      ...
# 123            0.95         additive                   0.5000
# 124            0.95         additive                   0.5000
# 125            0.95         additive                   0.5000
# 126            0.95         additive                   0.5000
# 127            0.95         additive                   0.5000
#
#      seasonality_prior_scale  \
# 0                       0.01
# 1                       0.01
# 2                       0.01
# 3                       0.01
# 4                       0.01
# ..                       ...
# 123                    10.00
# 124                    10.00
# 125                    10.00
# 126                    10.00
# 127                    10.00
#
#                                               holidays  holidays_prior_scale  \
# 0                           ds  holiday
# 0     2008-...                  0.01
# 1                           ds  holiday
# 0     2008-...                  0.01
# 2                           ds  holiday
# 0     2008-...                  0.10
# 3                           ds  holiday
# 0     2008-...                  0.10
# 4                           ds  holiday
# 0     2008-...                  1.00
# ..                                                 ...                   ...
# 123                         ds  holiday
# 0     2008-...                  0.10
# 124                         ds  holiday
# 0     2008-...                  1.00
# 125                         ds  holiday
# 0     2008-...                  1.00
# 126                         ds  holiday
# 0     2008-...                 10.00
# 127                         ds  holiday
# 0     2008-...                 10.00
#
#      changepoint_range         mse       rmse
# 0                  0.8   38.536611   6.207786
# 1                  0.9   39.007330   6.245585
# 2                  0.8   38.428768   6.199094
# 3                  0.9   38.862521   6.233981
# 4                  0.8   38.179507   6.178957
# ..                 ...         ...        ...
# 123                0.9  114.517625  10.701291
# 124                0.8   80.100486   8.949888
# 125                0.9  113.132132  10.636359
# 126                0.8   86.097870   9.278894
# 127                0.9  110.797047  10.526018
#
# [128 rows x 9 columns]]]

# %%
pred_mse_best_mse_RegMod_Opt
# Out:
#        prediction                            run_id
# id
# 32136   29.077647  d505347f8c394f9888c608992604065e
# 32137   27.065611  d505347f8c394f9888c608992604065e
# 32138   24.963615  d505347f8c394f9888c608992604065e
# 32139   24.364733  d505347f8c394f9888c608992604065e
# 32140   26.739614  d505347f8c394f9888c608992604065e
# 32141   31.884745  d505347f8c394f9888c608992604065e
# 32142   37.629810  d505347f8c394f9888c608992604065e
# 32143   41.190362  d505347f8c394f9888c608992604065e
# 32144   41.083677  d505347f8c394f9888c608992604065e
# 32145   38.033842  d505347f8c394f9888c608992604065e
# 32146   34.213895  d505347f8c394f9888c608992604065e
# 32147   31.615422  d505347f8c394f9888c608992604065e
# 32148   30.958481  d505347f8c394f9888c608992604065e
# 32149   31.857214  d505347f8c394f9888c608992604065e
# 32150   33.714379  d505347f8c394f9888c608992604065e
# 32151   36.264825  d505347f8c394f9888c608992604065e
# 32152   39.287136  d505347f8c394f9888c608992604065e
# 32153   42.032844  d505347f8c394f9888c608992604065e
# 32154   43.264566  d505347f8c394f9888c608992604065e
# 32155   42.094703  d505347f8c394f9888c608992604065e
# 32156   38.841454  d505347f8c394f9888c608992604065e
# 32157   34.945520  d505347f8c394f9888c608992604065e
# 32158   31.869780  d505347f8c394f9888c608992604065e
# 32159   29.967670  d505347f8c394f9888c608992604065e

# %%
ls_best_mse_best_mse_RegMod_Opt
# Out:
# [[{'index': 32135},
#   {'interval_width': 0.95,
#    'seasonality_mode': 'additive',
#    'changepoint_prior_scale': 0.0001,
#    'seasonality_prior_scale': 1.0,
#    'holidays':                        ds  holiday
#    0     2008-01-02 00:00:00  Holiday
#    1     2008-01-02 01:00:00  Holiday
#    2     2008-01-02 02:00:00  Holiday
#    3     2008-01-02 03:00:00  Holiday
#    4     2008-01-02 04:00:00  Holiday
#    ...                   ...      ...
#    34891 2011-12-25 19:00:00  Holiday
#    34892 2011-12-25 20:00:00  Holiday
#    34893 2011-12-25 21:00:00  Holiday
#    34894 2011-12-25 22:00:00  Holiday
#    34895 2011-12-25 23:00:00  Holiday
#
#    [960 rows x 2 columns],
#    'holidays_prior_scale': 0.1,
#    'changepoint_range': 0.8},
#        interval_width seasonality_mode  changepoint_prior_scale  \
#   0              0.95         additive                   0.0001
#   1              0.95         additive                   0.0001
#   2              0.95         additive                   0.0001
#   3              0.95         additive                   0.0001
#   4              0.95         additive                   0.0001
#   ..              ...              ...                      ...
#   123            0.95         additive                   0.5000
#   124            0.95         additive                   0.5000
#   125            0.95         additive                   0.5000
#   126            0.95         additive                   0.5000
#   127            0.95         additive                   0.5000
#
#        seasonality_prior_scale  \
#   0                       0.01
#   1                       0.01
#   2                       0.01
#   3                       0.01
#   4                       0.01
#   ..                       ...
#   123                    10.00
#   124                    10.00
#   125                    10.00
#   126                    10.00
#   127                    10.00
#
#                                                 holidays  holidays_prior_scale  \
#   0                           ds  holiday
#   0     2008-...                  0.01
#   1                           ds  holiday
#   0     2008-...                  0.01
#   2                           ds  holiday
#   0     2008-...                  0.10
#   3                           ds  holiday
#   0     2008-...                  0.10
#   4                           ds  holiday
#   0     2008-...                  1.00
#   ..                                                 ...                   ...
#   123                         ds  holiday
#   0     2008-...                  0.10
#   124                         ds  holiday
#   0     2008-...                  1.00
#   125                         ds  holiday
#   0     2008-...                  1.00
#   126                         ds  holiday
#   0     2008-...                 10.00
#   127                         ds  holiday
#   0     2008-...                 10.00
#
#        changepoint_range         mse       rmse
#   0                  0.8   38.536611   6.207786
#   1                  0.9   39.007330   6.245585
#   2                  0.8   38.428768   6.199094
#   3                  0.9   38.862521   6.233981
#   4                  0.8   38.179507   6.178957
#   ..                 ...         ...        ...
#   123                0.9  114.517625  10.701291
#   124                0.8   80.100486   8.949888
#   125                0.9  113.132132  10.636359
#   126                0.8   86.097870   9.278894
#   127                0.9  110.797047  10.526018
#
#   [128 rows x 9 columns]]]

# %%
m_mse_best_mse_RegMod_Opt

# %%
ls_publish_mse_best_mse_RegMod_Opt
# Out:
# [[{'index': 32135,
#    'metrics': {'mae': 5.7422959925925285,
#     'mse': 49.55838075217169,
#     'r2_score': 0.3469757490357219},
#    'params': {'building_nr': 5,
#     'datetime': datetime.datetime(2011, 9, 1, 23, 0)},
#    'forecast':        prediction                            run_id
#    id
#    32136   29.077647  d505347f8c394f9888c608992604065e
#    32137   27.065611  d505347f8c394f9888c608992604065e
#    32138   24.963615  d505347f8c394f9888c608992604065e
#    32139   24.364733  d505347f8c394f9888c608992604065e
#    32140   26.739614  d505347f8c394f9888c608992604065e
#    32141   31.884745  d505347f8c394f9888c608992604065e
#    32142   37.629810  d505347f8c394f9888c608992604065e
#    32143   41.190362  d505347f8c394f9888c608992604065e
#    32144   41.083677  d505347f8c394f9888c608992604065e
#    32145   38.033842  d505347f8c394f9888c608992604065e
#    32146   34.213895  d505347f8c394f9888c608992604065e
#    32147   31.615422  d505347f8c394f9888c608992604065e
#    32148   30.958481  d505347f8c394f9888c608992604065e
#    32149   31.857214  d505347f8c394f9888c608992604065e
#    32150   33.714379  d505347f8c394f9888c608992604065e
#    32151   36.264825  d505347f8c394f9888c608992604065e
#    32152   39.287136  d505347f8c394f9888c608992604065e
#    32153   42.032844  d505347f8c394f9888c608992604065e
#    32154   43.264566  d505347f8c394f9888c608992604065e
#    32155   42.094703  d505347f8c394f9888c608992604065e
#    32156   38.841454  d505347f8c394f9888c608992604065e
#    32157   34.945520  d505347f8c394f9888c608992604065e
#    32158   31.869780  d505347f8c394f9888c608992604065e
#    32159   29.967670  d505347f8c394f9888c608992604065e}]]
