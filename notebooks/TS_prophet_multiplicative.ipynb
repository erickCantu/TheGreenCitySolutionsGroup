# %% [markdown]
# # TS Prophet

# %%
# %matplotlib inline
import pandas as pd
from prophet import Prophet

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
# sns.set_style(
#     style='darkgrid', 
#     rc={'axes.facecolor': 'white', 'grid.color': '.8'}
# )
# NF_ORANGE = '#ff5a36'
# NF_BLUE = '#163251'
# cmaps_hex = ['#193251','#FF5A36','#696969', '#7589A2','#FF5A36', '#DB6668']
# sns.set_palette(palette=cmaps_hex)
# sns_c = sns.color_palette(palette=cmaps_hex)
# %matplotlib inline
# from pandas.plotting import register_matplotlib_converters
# register_matplotlib_converters()

# plt.rcParams['figure.figsize'] = [12, 6]
# plt.rcParams['figure.dpi'] = 100

# %%
# Load data
df = pd.read_csv("../data/preprocessed/Building_4.csv").astype({'datetime': 'datetime64'})#.set_index('datetime')

# %%
# Add a total load
df['total_load_kWh'] = df['equipment_electric_power_kWh'] + df['dhw_heating_kWh'] + df['cooling_load_kWh']

# Add a total load without cooling
df['total_load_wo_cooling_kWh'] = df['equipment_electric_power_kWh'] + df['dhw_heating_kWh']

# Add a net load
df['net_load_kWh'] = df['total_load_kWh'] - df['solar_generation_kW']

# %%
df['net_load_kWh'].plot()
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['datetime', 'daylight_savings', 'indoor_temp', 'avg_unmet_cooling_temp',
#        'indoor_hum', 'equipment_electric_power_kWh', 'dhw_heating_kWh',
#        'cooling_load_kWh', 'solar_generation_W_kW', 'outdoor_temp',
#        'outdoor_hum', 'diffuse_solar_W_m2', 'direct_solar_W_m2',
#        'pred_6h_outdoor_temp', 'pred_12h_outdoor_temp',
#        'pred_24h_outdoor_temp', 'pred_6h_outdoor_hum', 'pred_12h_outdoor_hum',
#        'pred_24h_outdoor_hum', 'pred_6h_diffuse_solar_W_m2',
#        'pred_12h_diffuse_solar_W_m2', 'pred_24h_diffuse_solar_W_m2',
#        'pred_6h_direct_solar_W_m2', 'pred_12h_direct_solar_W_m2',
#        'pred_24h_direct_solar_W_m2', 'holiday', 'workday',
#        'solar_generation_kW', 'total_load_kWh', 'total_load_wo_cooling_kWh',
#        'net_load_kWh'],
#       dtype='object')

# %%
df = df.rename(columns={'datetime':'ds',
                        'net_load_kWh':'y'})
df.head(5)
# Out:
#                    ds  daylight_savings  indoor_temp  avg_unmet_cooling_temp  \
# 0 2008-01-02 00:00:00               0.0        20.42                     0.0
# 1 2008-01-02 01:00:00               0.0        20.16                     0.0
# 2 2008-01-02 02:00:00               0.0        20.00                     0.0
# 3 2008-01-02 03:00:00               0.0        19.78                     0.0
# 4 2008-01-02 04:00:00               0.0        19.66                     0.0
#
#    indoor_hum  equipment_electric_power_kWh  dhw_heating_kWh  \
# 0       59.00                          0.44                0
# 1       59.61                          0.44                0
# 2       59.95                          0.44                0
# 3       60.31                          0.44                0
# 4       60.29                          0.44                0
#
#    cooling_load_kWh  solar_generation_W_kW  outdoor_temp  ...  \
# 0               0.0                    0.0          9.40  ...
# 1               0.0                    0.0          7.61  ...
# 2               0.0                    0.0          8.11  ...
# 3               0.0                    0.0          8.36  ...
# 4               0.0                    0.0          8.78  ...
#
#    pred_24h_diffuse_solar_W_m2  pred_6h_direct_solar_W_m2  \
# 0                          0.0                      -0.00
# 1                          0.0                       1.11
# 2                          0.0                       1.74
# 3                         -0.0                       1.09
# 4                          0.0                       1.78
#
#    pred_12h_direct_solar_W_m2  pred_24h_direct_solar_W_m2  holiday  workday  \
# 0                        5.32                         0.0     True    False
# 1                        2.04                        -0.0     True    False
# 2                        1.04                         0.0     True    False
# 3                        0.99                         0.0     True    False
# 4                        0.84                         0.0     True    False
#
#    solar_generation_kW  total_load_kWh  total_load_wo_cooling_kWh     y
# 0                  0.0            0.44                       0.44  0.44
# 1                  0.0            0.44                       0.44  0.44
# 2                  0.0            0.44                       0.44  0.44
# 3                  0.0            0.44                       0.44  0.44
# 4                  0.0            0.44                       0.44  0.44
#
# [5 rows x 31 columns]

# %%
my_model = Prophet(interval_width = 0.8, seasonality_mode="multiplicative")

# %%
my_model.fit(df)
# Out:
# Initial log joint probability = -1196.03
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       57324.8      0.155656       15524.4      0.8592     0.08592      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199         58634     0.0615933       9895.02           1           1      247
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       59420.2      0.122273       7156.74      0.8596      0.8596      364
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       59700.4     0.0023254       2883.18      0.2464      0.2464      480
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       59943.8     0.0202089       1783.64           1           1      610
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       60009.9    0.00148496       715.993           1           1      737
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       60062.5    0.00418047       474.635      0.3565           1      854
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      791       60110.6   0.000149272       852.496   4.241e-07       0.001     1016  LS failed, Hessian reset
#      799       60111.2    0.00195968       2731.66           1           1     1024
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       60128.9    0.00416414       2655.78           1           1     1139
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       60143.6     0.0025926       2134.11           1           1     1254
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       60191.8     0.0101628       761.649           1           1     1376
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       60223.1   0.000722606       728.622           1           1     1498
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       60233.1    0.00134609       649.544           1           1     1617
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       60246.9      0.017799        3341.8           1           1     1733
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       60259.7    0.00342718       1436.58      0.3649           1     1858
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       60286.1     0.0122508       1927.76       1.669      0.1669     1985
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       60301.5     0.0160036       1960.35           1           1     2098
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       60329.4    0.00330257       464.767           1           1     2225
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       60345.3    0.00217959       2335.07     0.03984           1     2355
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       60356.2    0.00736656       656.048           1           1     2488
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       60362.3   0.000251067       464.808           1           1     2610
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       60367.7    0.00040752       875.141      0.7956      0.7956     2732
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       60370.5    0.00585144       649.994           1           1     2851
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       60372.9    0.00123072       311.784           1           1     2971
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       60375.3    0.00425501       985.196           1           1     3083
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       60384.2   0.000798473       875.212     0.09832    0.009832     3204
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699       60387.1     0.0109063       5735.67           1           1     3321
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       60391.8   0.000144318       594.473           1           1     3437
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2899       60396.3     0.0026759       238.572           1           1     3553
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999       60400.1   6.15202e-05       141.582           1           1     3671
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099       60404.7    0.00589899       1284.69           1           1     3789
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199       60408.2   0.000870042       719.715           1           1     3915
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3299       60409.6    0.00422382       1950.28           1           1     4034
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399       60411.3    0.00032612        405.35      0.5288      0.5288     4154
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3499       60413.3    0.00161012       3146.68           1           1     4278
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3523       60413.5   0.000144596       84.0828           1           1     4305
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
future_dates = my_model.make_future_dataframe(periods = 24*365, freq='H',include_history=False)
future_dates.tail()
# Out:
#                       ds
# 8755 2012-12-30 19:00:00
# 8756 2012-12-30 20:00:00
# 8757 2012-12-30 21:00:00
# 8758 2012-12-30 22:00:00
# 8759 2012-12-30 23:00:00

# %%
forecast = my_model.predict(future_dates)
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
#                       ds       yhat  yhat_lower  yhat_upper
# 8755 2012-12-30 19:00:00 -32.938502 -385.035163  304.144085
# 8756 2012-12-30 20:00:00 -44.488153 -528.188130  417.034114
# 8757 2012-12-30 21:00:00 -51.885270 -608.592878  492.169176
# 8758 2012-12-30 22:00:00 -56.310851 -672.988423  523.366350
# 8759 2012-12-30 23:00:00 -58.875035 -684.034066  539.612665

# %%
fig = my_model.plot(forecast, uncertainty=True)

# %%
fig = my_model.plot_components(forecast)

# %%
from prophet.plot import plot_plotly, plot_components_plotly
plot_plotly(my_model, forecast)
